# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".jpg":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign_train = np.array(Dataset_loader('D:/DATA PROJECT/code ddsm 2//benign_train',224))
malign_train = np.array(Dataset_loader('D:/DATA PROJECT/code ddsm 2//malignant_train',224))
benign_test = np.array(Dataset_loader('D:/DATA PROJECT/code ddsm 2/benign_test',224))
malign_test = np.array(Dataset_loader('D:/DATA PROJECT/code ddsm 2//malignant_test',224))
benign_validation = np.array(Dataset_loader('D:/DATA PROJECT/code ddsm 2//benign_validation',224))
malign_validation = np.array(Dataset_loader('D:/DATA PROJECT/code ddsm 2//malignant_validation',224))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 300/300 [00:52<00:00,  5.69it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 300/300 [00:48<00:00,  6.15it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:18<00:00,  5.34it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:15<00:00,  6.61it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:21<00:00,  4.63it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:19<00:00,  5.16it/s]

# %%
print('Resized Dimensions : ',benign_train.shape)
print('Resized Dimensions : ',benign_test.shape)
print('Resized Dimensions : ',malign_train.shape)
print('Resized Dimensions : ',malign_test.shape)
print('Resized Dimensions : ',malign_validation.shape)
print('Resized Dimensions : ',malign_validation.shape)
# Out:
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)

# %%
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))
benign_validation_label = np.zeros(len(benign_validation))
malign_validation_label = np.ones(len(malign_validation))

# %%
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)
X_val = np.concatenate((benign_validation, malign_validation),axis=0)
Y_val = np.concatenate((benign_validation_label, malign_validation_label),axis=0)

# %%
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# %%
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
s = np.arange(X_val.shape[0])
np.random.shuffle(s)
X_val = X_val[s]
Y_val = Y_val[s]

# %%
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)
Y_val = to_categorical(Y_val, num_classes= 2)

# %%
# # Display first 15 images , and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')
plt.show()

# %%
def build_model(backbone, learning_rate=1e-5):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(2, activation='softmax'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=learning_rate),
        metrics=['accuracy']
    )
    
    return model

# %%
K.clear_session()
gc.collect()

resnet = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)


 


model = build_model(resnet ,learning_rate = 1e-5)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1920)              0
#
#  batch_normalization (BatchN  (None, 1920)             7680
#  ormalization)
#
#  dense (Dense)               (None, 128)               245888
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 18,575,810
# Trainable params: 18,342,914
# Non-trainable params: 232,896
# _________________________________________________________________

# %%
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=10,verbose=1,factor=0.2, min_lr=1e-7)
early_stopping = EarlyStopping(monitor='val_accuracy', patience=20,verbose=1, mode='max')

# Checkpoint
filepath="memo3.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5772/1472936906.py in <module>
# ----> 1 learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=10,verbose=1,factor=0.2, min_lr=1e-7)
#       2 early_stopping = EarlyStopping(monitor='val_accuracy', patience=20,verbose=1, mode='max')
#       3
#       4 # Checkpoint
#       5 filepath="memo3.best.hdf5"
#
# NameError: name 'ReduceLROnPlateau' is not defined

# %%
history = model.fit(
    X_train,Y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val,Y_val),
    callbacks=[learn_control, checkpoint ,early_stopping],
    shuffle=True
)
# Out:
# Epoch 1/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8388 - accuracy: 0.5017
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 500s 25s/step - loss: 0.8388 - accuracy: 0.5017 - val_loss: 0.8979 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 2/100
# 19/19 [==============================] - ETA: 0s - loss: 0.7403 - accuracy: 0.5433
# Epoch 00002: val_accuracy did not improve from 0.50000
# 19/19 [==============================] - 492s 26s/step - loss: 0.7403 - accuracy: 0.5433 - val_loss: 0.7780 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 3/100
# 19/19 [==============================] - ETA: 0s - loss: 0.6687 - accuracy: 0.6067
# Epoch 00003: val_accuracy did not improve from 0.50000
# 19/19 [==============================] - 469s 25s/step - loss: 0.6687 - accuracy: 0.6067 - val_loss: 0.7037 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 4/100
# 19/19 [==============================] - ETA: 0s - loss: 0.5974 - accuracy: 0.6783
# Epoch 00004: val_accuracy improved from 0.50000 to 0.51000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 478s 25s/step - loss: 0.5974 - accuracy: 0.6783 - val_loss: 0.6324 - val_accuracy: 0.5100 - lr: 1.0000e-05
# Epoch 5/100
# 19/19 [==============================] - ETA: 0s - loss: 0.5408 - accuracy: 0.7567
# Epoch 00005: val_accuracy improved from 0.51000 to 0.53500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 472s 25s/step - loss: 0.5408 - accuracy: 0.7567 - val_loss: 0.5759 - val_accuracy: 0.5350 - lr: 1.0000e-05
# Epoch 6/100
# 19/19 [==============================] - ETA: 0s - loss: 0.4788 - accuracy: 0.8017
# Epoch 00006: val_accuracy improved from 0.53500 to 0.58000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 501s 27s/step - loss: 0.4788 - accuracy: 0.8017 - val_loss: 0.5407 - val_accuracy: 0.5800 - lr: 1.0000e-05
# Epoch 7/100
# 19/19 [==============================] - ETA: 0s - loss: 0.4422 - accuracy: 0.8333
# Epoch 00007: val_accuracy improved from 0.58000 to 0.64000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 493s 26s/step - loss: 0.4422 - accuracy: 0.8333 - val_loss: 0.5246 - val_accuracy: 0.6400 - lr: 1.0000e-05
# Epoch 8/100
# 19/19 [==============================] - ETA: 0s - loss: 0.4017 - accuracy: 0.8750
# Epoch 00008: val_accuracy improved from 0.64000 to 0.69500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 469s 25s/step - loss: 0.4017 - accuracy: 0.8750 - val_loss: 0.5060 - val_accuracy: 0.6950 - lr: 1.0000e-05
# Epoch 9/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3588 - accuracy: 0.8933
# Epoch 00009: val_accuracy improved from 0.69500 to 0.73500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 469s 25s/step - loss: 0.3588 - accuracy: 0.8933 - val_loss: 0.4780 - val_accuracy: 0.7350 - lr: 1.0000e-05
# Epoch 10/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3278 - accuracy: 0.9183
# Epoch 00010: val_accuracy improved from 0.73500 to 0.78000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 465s 25s/step - loss: 0.3278 - accuracy: 0.9183 - val_loss: 0.4649 - val_accuracy: 0.7800 - lr: 1.0000e-05
# Epoch 11/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2803 - accuracy: 0.9467
# Epoch 00011: val_accuracy improved from 0.78000 to 0.80500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 481s 25s/step - loss: 0.2803 - accuracy: 0.9467 - val_loss: 0.4500 - val_accuracy: 0.8050 - lr: 1.0000e-05
# Epoch 12/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2545 - accuracy: 0.9467
# Epoch 00012: val_accuracy improved from 0.80500 to 0.83000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 477s 25s/step - loss: 0.2545 - accuracy: 0.9467 - val_loss: 0.4220 - val_accuracy: 0.8300 - lr: 1.0000e-05
# Epoch 13/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.9717
# Epoch 00013: val_accuracy improved from 0.83000 to 0.85500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 538s 29s/step - loss: 0.2184 - accuracy: 0.9717 - val_loss: 0.3927 - val_accuracy: 0.8550 - lr: 1.0000e-05
# Epoch 14/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1779 - accuracy: 0.9817
# Epoch 00014: val_accuracy improved from 0.85500 to 0.87500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 526s 28s/step - loss: 0.1779 - accuracy: 0.9817 - val_loss: 0.3708 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Epoch 15/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9950
# Epoch 00015: val_accuracy improved from 0.87500 to 0.88500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 567s 30s/step - loss: 0.1500 - accuracy: 0.9950 - val_loss: 0.3572 - val_accuracy: 0.8850 - lr: 1.0000e-05
# Epoch 16/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9900
# Epoch 00016: val_accuracy improved from 0.88500 to 0.90000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 526s 28s/step - loss: 0.1378 - accuracy: 0.9900 - val_loss: 0.3413 - val_accuracy: 0.9000 - lr: 1.0000e-05
# Epoch 17/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9950
# Epoch 00017: val_accuracy improved from 0.90000 to 0.91000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 551s 29s/step - loss: 0.1102 - accuracy: 0.9950 - val_loss: 0.3210 - val_accuracy: 0.9100 - lr: 1.0000e-05
# Epoch 18/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9933
# Epoch 00018: val_accuracy improved from 0.91000 to 0.92000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 552s 29s/step - loss: 0.1116 - accuracy: 0.9933 - val_loss: 0.3124 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 19/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 1.0000
# Epoch 00019: val_accuracy improved from 0.92000 to 0.93000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 480s 25s/step - loss: 0.0914 - accuracy: 1.0000 - val_loss: 0.3031 - val_accuracy: 0.9300 - lr: 1.0000e-05
# Epoch 20/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 1.0000
# Epoch 00020: val_accuracy improved from 0.93000 to 0.93500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 454s 24s/step - loss: 0.0728 - accuracy: 1.0000 - val_loss: 0.2832 - val_accuracy: 0.9350 - lr: 1.0000e-05
# Epoch 21/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 1.0000
# Epoch 00021: val_accuracy did not improve from 0.93500
# 19/19 [==============================] - 472s 25s/step - loss: 0.0603 - accuracy: 1.0000 - val_loss: 0.2671 - val_accuracy: 0.9350 - lr: 1.0000e-05
# Epoch 22/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9983
# Epoch 00022: val_accuracy did not improve from 0.93500
# 19/19 [==============================] - 454s 24s/step - loss: 0.0575 - accuracy: 0.9983 - val_loss: 0.2638 - val_accuracy: 0.9350 - lr: 1.0000e-05
# Epoch 23/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 1.0000
# Epoch 00023: val_accuracy improved from 0.93500 to 0.94500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 458s 24s/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.2631 - val_accuracy: 0.9450 - lr: 1.0000e-05
# Epoch 24/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0424 - accuracy: 1.0000
# Epoch 00024: val_accuracy did not improve from 0.94500
# 19/19 [==============================] - 457s 24s/step - loss: 0.0424 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9450 - lr: 1.0000e-05
# Epoch 25/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 1.0000
# Epoch 00025: val_accuracy did not improve from 0.94500
# 19/19 [==============================] - 454s 24s/step - loss: 0.0363 - accuracy: 1.0000 - val_loss: 0.2458 - val_accuracy: 0.9400 - lr: 1.0000e-05
# Epoch 26/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 1.0000
# Epoch 00026: val_accuracy did not improve from 0.94500
# 19/19 [==============================] - 459s 24s/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 0.2374 - val_accuracy: 0.9450 - lr: 1.0000e-05
# Epoch 27/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 1.0000
# Epoch 00027: val_accuracy did not improve from 0.94500
# 19/19 [==============================] - 454s 24s/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.2400 - val_accuracy: 0.9450 - lr: 1.0000e-05
# Epoch 28/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 1.0000
# Epoch 00028: val_accuracy improved from 0.94500 to 0.95000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 465s 25s/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.2390 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 29/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9967
# Epoch 00029: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 463s 24s/step - loss: 0.0385 - accuracy: 0.9967 - val_loss: 0.2412 - val_accuracy: 0.9400 - lr: 1.0000e-05
# Epoch 30/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 521s 28s/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.2544 - val_accuracy: 0.9400 - lr: 1.0000e-05
# Epoch 31/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 1.0000
# Epoch 00031: val_accuracy improved from 0.95000 to 0.95500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 522s 28s/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.2395 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 32/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 1.0000
# Epoch 00032: val_accuracy did not improve from 0.95500
# 19/19 [==============================] - 493s 26s/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 33/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 1.0000
# Epoch 00033: val_accuracy did not improve from 0.95500
# 19/19 [==============================] - 521s 27s/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.2173 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 34/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 1.0000
# Epoch 00034: val_accuracy did not improve from 0.95500
# 19/19 [==============================] - 462s 24s/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.2181 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 35/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 1.0000
# Epoch 00035: val_accuracy did not improve from 0.95500
# 19/19 [==============================] - 455s 24s/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 36/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9983
# Epoch 00036: val_accuracy did not improve from 0.95500
# 19/19 [==============================] - 453s 24s/step - loss: 0.0215 - accuracy: 0.9983 - val_loss: 0.2018 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 37/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 1.0000
# Epoch 00037: val_accuracy improved from 0.95500 to 0.96000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 455s 24s/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.1964 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 38/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9950
# Epoch 00038: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 450s 24s/step - loss: 0.0253 - accuracy: 0.9950 - val_loss: 0.2000 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 39/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 452s 24s/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 40/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 41/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 1.0000
# Epoch 00041: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 452s 24s/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 42/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 1.0000
# Epoch 00042: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 452s 24s/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 43/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 458s 24s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 44/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 00044: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.1941 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 45/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 46/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2073 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 47/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 1.0000
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
#
# Epoch 00047: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 48/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9600 - lr: 2.0000e-06
# Epoch 49/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.2034 - val_accuracy: 0.9600 - lr: 2.0000e-06
# Epoch 50/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 452s 24s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9600 - lr: 2.0000e-06
# Epoch 51/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9983
# Epoch 00051: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0144 - accuracy: 0.9983 - val_loss: 0.1999 - val_accuracy: 0.9600 - lr: 2.0000e-06
# Epoch 52/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 450s 24s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9600 - lr: 2.0000e-06
# Epoch 53/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 00053: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9600 - lr: 2.0000e-06
# Epoch 54/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9983
# Epoch 00054: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0137 - accuracy: 0.9983 - val_loss: 0.1965 - val_accuracy: 0.9600 - lr: 2.0000e-06
# Epoch 55/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9600 - lr: 2.0000e-06
# Epoch 56/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9600 - lr: 2.0000e-06
# Epoch 57/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
#
# Epoch 00057: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 451s 24s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9600 - lr: 2.0000e-06
# Epoch 00057: early stopping

# %%
model.load_weights("memo3.best.hdf5")

# %%
Y_val_pred = model.predict(X_val)

# %%
accuracy_score(np.argmax(Y_val, axis=1), np.argmax(Y_val_pred, axis=1))
# Out:
# 0.96

# %%
train_loss_fe = history.history['loss']
train_acc_fe = history.history['accuracy']
val_loss_fe = history.history['val_loss']
val_acc_fe = history.history['val_accuracy']

epochs_fe = range(1, len(train_acc_fe)+1)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_fe, train_acc_fe, label='Training Accuracy')
plt.plot(epochs_fe, val_acc_fe, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_fe,train_loss_fe , label='Training Loss')
plt.plot(epochs_fe, val_loss_fe, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from time import sleep
import time
start = time.process_time() 
Y_pred = model.predict(X_test)
end = time.process_time()
print("Time per image: {} ".format((end-start)/len(X_test)))
# Out:
# Time per image: 0.502890625

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for breast cancer')
# Out:
# Confusion matrix, without normalization
# [[79 21]
#  [ 9 91]]

# %%
from sklearn.metrics import classification_report
print(classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.79      0.84       100
#            1       0.81      0.91      0.86       100
#
#     accuracy                           0.85       200
#    macro avg       0.86      0.85      0.85       200
# weighted avg       0.86      0.85      0.85       200

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

plt.close()
