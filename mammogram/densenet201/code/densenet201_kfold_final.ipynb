# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".jpg":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_train',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_train',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_test',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_test',224))
benign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_validation',224))
malign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_validation',224))
# Out:
# 100%|██████████| 300/300 [00:41<00:00,  7.28it/s]
# 100%|██████████| 300/300 [00:37<00:00,  8.05it/s]
# 100%|██████████| 100/100 [00:16<00:00,  5.89it/s]
# 100%|██████████| 100/100 [00:12<00:00,  8.13it/s]
# 100%|██████████| 100/100 [00:18<00:00,  5.45it/s]
# 100%|██████████| 100/100 [00:14<00:00,  6.68it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('Resized Dimensions : ',benign_train.shape)
print('Resized Dimensions : ',benign_test.shape)
print('Resized Dimensions : ',malign_train.shape)
print('Resized Dimensions : ',malign_test.shape)
print('Resized Dimensions : ',malign_validation.shape)
print('Resized Dimensions : ',malign_validation.shape)
# Out:
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)

# %%
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))
benign_validation_label = np.zeros(len(benign_validation))
malign_validation_label = np.ones(len(malign_validation))

# %%
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)
X_val = np.concatenate((benign_validation, malign_validation),axis=0)
Y_val = np.concatenate((benign_validation_label, malign_validation_label),axis=0)

# %%
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# %%
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
s = np.arange(X_val.shape[0])
np.random.shuffle(s)
X_val = X_val[s]
Y_val = Y_val[s]

# %%
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)
Y_val = to_categorical(Y_val, num_classes= 2)

# %%
acc_per_fold = []
loss_per_fold = []
sens_per_fold = []
spec_per_fold = []
prec_per_fold = []

# %%
inputs = np.concatenate((X_train, X_val), axis=0)
targets = np.concatenate((Y_train, Y_val), axis=0)

# %%
# # Display first 15 images , and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(targets[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(inputs[i], interpolation='nearest')
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications.inception_v3 import InceptionV3
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
kfold = KFold(n_splits=5, shuffle=True)

# K-fold Cross Validation model evaluation

fold_no = 1
for train, test in kfold.split(inputs, targets):
    
    
    def build_model(backbone, learning_rate=1e-5):
        
        model = Sequential()
        model.add(backbone)
        model.add(layers.GlobalAveragePooling2D())
        model.add(layers.Dropout(0.5))
        model.add(layers.BatchNormalization())
        model.add(Dense(128, activation='relu'))
        model.add(layers.Dense(2, activation='softmax'))
        
    
    
        model.compile(loss='binary_crossentropy',optimizer=Adam(learning_rate=learning_rate),metrics=['accuracy'])
       # model.compile(optimizer='adam',loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
    
        return model


    resnet = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3))
   # tf.keras.utils.plot_model

 
    model = build_model(resnet ,learning_rate = 1e-5)
    
    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    history = model.fit(
    inputs[train], targets[train],
    epochs=25,
    batch_size=32,
    validation_data=(inputs[test],targets[test]),
    shuffle=True
    )
    
    predictions = model.predict(X_test)
    true_classes = Y_test
    # evaluate validation performance
    print("***Performance on Validation data***")    
    cm = confusion_matrix(np.argmax(true_classes, axis=1), np.argmax(predictions, axis=1))
    print(cm)
    print(classification_report( np.argmax(true_classes, axis=1), np.argmax(predictions, axis=1)))

    TP = cm[1,1] # true positive 
    TN = cm[0,0] # true negative
    FN = cm[1,0] # false negative
    FP = cm[0,1] # false positive
    print(f"  {TP}\n  {TN}\n {FP}\n  {FN}\n ")
    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP/(TP+FN)
    # Specificity or true negative rate
    TNR = TN/(TN+FP) 
    # Precision or positive predictive value
    PPV = TP/(TP+FP)
    # Negative predictive value
    NPV = TN/(TN+FN)
    # Fall out or false positive rate
    FPR = FP/(FP+TN)
    # False negative rate
    FNR = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP)



    print(f"Trial Metrics:")
    print(f"Sensitivity: {TPR}\nSpecifity: {TNR}\nPrecision: {PPV} ")
    

    scores = model.evaluate(X_test, Y_test, verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%' )
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])
    sens_per_fold.append(TPR) 
    spec_per_fold.append(TNR)  
    prec_per_fold.append(PPV) 
   
    

    fold_no = fold_no + 1


# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)} (+- {np.std(loss_per_fold)})')
print(f'> Sensitivity: {np.mean(sens_per_fold)} (+- {np.std(sens_per_fold)})')
print(f'> Specifity: {np.mean(spec_per_fold)} (+- {np.std(spec_per_fold)})')
print(f'> Precision: {np.mean(prec_per_fold)} (+- {np.std(prec_per_fold)})')
print('------------------------------------------------------------------------')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# 74850304/74836368 [==============================] - 1s 0us/step
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/25
# 20/20 [==============================] - 69s 1s/step - loss: 0.8342 - accuracy: 0.5047 - val_loss: 0.9838 - val_accuracy: 0.5125
# Epoch 2/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.6905 - accuracy: 0.5562 - val_loss: 0.8377 - val_accuracy: 0.5125
# Epoch 3/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.5875 - accuracy: 0.6359 - val_loss: 0.7389 - val_accuracy: 0.5125
# Epoch 4/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.5233 - accuracy: 0.7422 - val_loss: 0.6657 - val_accuracy: 0.5375
# Epoch 5/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.4664 - accuracy: 0.8016 - val_loss: 0.6196 - val_accuracy: 0.6062
# Epoch 6/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.4094 - accuracy: 0.8594 - val_loss: 0.5928 - val_accuracy: 0.7125
# Epoch 7/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.3728 - accuracy: 0.8875 - val_loss: 0.5606 - val_accuracy: 0.7250
# Epoch 8/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.3196 - accuracy: 0.9141 - val_loss: 0.5419 - val_accuracy: 0.7375
# Epoch 9/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.2873 - accuracy: 0.9094 - val_loss: 0.5192 - val_accuracy: 0.7688
# Epoch 10/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2420 - accuracy: 0.9484 - val_loss: 0.4941 - val_accuracy: 0.7688
# Epoch 11/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2196 - accuracy: 0.9516 - val_loss: 0.4748 - val_accuracy: 0.8000
# Epoch 12/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1752 - accuracy: 0.9688 - val_loss: 0.4522 - val_accuracy: 0.8062
# Epoch 13/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1516 - accuracy: 0.9719 - val_loss: 0.4153 - val_accuracy: 0.8500
# Epoch 14/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1183 - accuracy: 0.9859 - val_loss: 0.4218 - val_accuracy: 0.8375
# Epoch 15/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1051 - accuracy: 0.9875 - val_loss: 0.4081 - val_accuracy: 0.8438
# Epoch 16/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0771 - accuracy: 0.9937 - val_loss: 0.3868 - val_accuracy: 0.8562
# Epoch 17/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0717 - accuracy: 0.9969 - val_loss: 0.3892 - val_accuracy: 0.8438
# Epoch 18/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0533 - accuracy: 0.9984 - val_loss: 0.3713 - val_accuracy: 0.8562
# Epoch 19/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0492 - accuracy: 0.9969 - val_loss: 0.3997 - val_accuracy: 0.8625
# Epoch 20/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0501 - accuracy: 0.9984 - val_loss: 0.3868 - val_accuracy: 0.8750
# Epoch 21/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0351 - accuracy: 0.9984 - val_loss: 0.3745 - val_accuracy: 0.8687
# Epoch 22/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.3640 - val_accuracy: 0.8750
# Epoch 23/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.3746 - val_accuracy: 0.8938
# Epoch 24/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.3733 - val_accuracy: 0.8813
# Epoch 25/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.3738 - val_accuracy: 0.8750
# ***Performance on Validation data***
# [[83 17]
#  [ 7 93]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87       100
#            1       0.85      0.93      0.89       100
#
#     accuracy                           0.88       200
#    macro avg       0.88      0.88      0.88       200
# weighted avg       0.88      0.88      0.88       200
#
#   93
#   83
#  17
#   7
#
# Trial Metrics:
# Sensitivity: 0.93
# Specifity: 0.83
# Precision: 0.8454545454545455
# Score for fold 1: loss of 0.3044174313545227; accuracy of 87.99999952316284%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/25
# 20/20 [==============================] - 51s 1s/step - loss: 0.7235 - accuracy: 0.5484 - val_loss: 0.7038 - val_accuracy: 0.5813
# Epoch 2/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.6410 - accuracy: 0.6859 - val_loss: 0.6654 - val_accuracy: 0.6375
# Epoch 3/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.5622 - accuracy: 0.7500 - val_loss: 0.6263 - val_accuracy: 0.6938
# Epoch 4/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.5127 - accuracy: 0.7875 - val_loss: 0.5853 - val_accuracy: 0.7125
# Epoch 5/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.4617 - accuracy: 0.8391 - val_loss: 0.5451 - val_accuracy: 0.7312
# Epoch 6/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.4274 - accuracy: 0.8578 - val_loss: 0.5086 - val_accuracy: 0.7625
# Epoch 7/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.3942 - accuracy: 0.8859 - val_loss: 0.4775 - val_accuracy: 0.8125
# Epoch 8/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.3517 - accuracy: 0.9094 - val_loss: 0.4535 - val_accuracy: 0.8313
# Epoch 9/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.3269 - accuracy: 0.9250 - val_loss: 0.4340 - val_accuracy: 0.8250
# Epoch 10/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.2935 - accuracy: 0.9359 - val_loss: 0.4145 - val_accuracy: 0.8313
# Epoch 11/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2759 - accuracy: 0.9359 - val_loss: 0.3912 - val_accuracy: 0.8313
# Epoch 12/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2678 - accuracy: 0.9328 - val_loss: 0.3724 - val_accuracy: 0.8562
# Epoch 13/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.2248 - accuracy: 0.9594 - val_loss: 0.3574 - val_accuracy: 0.8562
# Epoch 14/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1991 - accuracy: 0.9594 - val_loss: 0.3490 - val_accuracy: 0.8562
# Epoch 15/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1766 - accuracy: 0.9719 - val_loss: 0.3325 - val_accuracy: 0.8562
# Epoch 16/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1545 - accuracy: 0.9719 - val_loss: 0.3214 - val_accuracy: 0.8687
# Epoch 17/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.1395 - accuracy: 0.9766 - val_loss: 0.3191 - val_accuracy: 0.8562
# Epoch 18/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.1311 - accuracy: 0.9812 - val_loss: 0.3036 - val_accuracy: 0.8562
# Epoch 19/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1093 - accuracy: 0.9875 - val_loss: 0.2980 - val_accuracy: 0.8625
# Epoch 20/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0974 - accuracy: 0.9875 - val_loss: 0.3054 - val_accuracy: 0.8625
# Epoch 21/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0950 - accuracy: 0.9844 - val_loss: 0.2929 - val_accuracy: 0.8687
# Epoch 22/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0921 - accuracy: 0.9828 - val_loss: 0.2844 - val_accuracy: 0.8750
# Epoch 23/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0644 - accuracy: 0.9969 - val_loss: 0.2859 - val_accuracy: 0.8687
# Epoch 24/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0638 - accuracy: 0.9969 - val_loss: 0.2801 - val_accuracy: 0.8813
# Epoch 25/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0552 - accuracy: 0.9953 - val_loss: 0.2704 - val_accuracy: 0.8813
# ***Performance on Validation data***
# [[79 21]
#  [ 2 98]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.79      0.87       100
#            1       0.82      0.98      0.89       100
#
#     accuracy                           0.89       200
#    macro avg       0.90      0.89      0.88       200
# weighted avg       0.90      0.89      0.88       200
#
#   98
#   79
#  21
#   2
#
# Trial Metrics:
# Sensitivity: 0.98
# Specifity: 0.79
# Precision: 0.8235294117647058
# Score for fold 2: loss of 0.2914942800998688; accuracy of 88.49999904632568%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/25
# 20/20 [==============================] - 52s 1s/step - loss: 0.7360 - accuracy: 0.5437 - val_loss: 0.6698 - val_accuracy: 0.6313
# Epoch 2/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.6303 - accuracy: 0.6859 - val_loss: 0.6142 - val_accuracy: 0.7375
# Epoch 3/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.5435 - accuracy: 0.7703 - val_loss: 0.5730 - val_accuracy: 0.7125
# Epoch 4/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.5005 - accuracy: 0.8125 - val_loss: 0.5341 - val_accuracy: 0.7437
# Epoch 5/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.4360 - accuracy: 0.8344 - val_loss: 0.4997 - val_accuracy: 0.7625
# Epoch 6/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.3879 - accuracy: 0.8813 - val_loss: 0.4691 - val_accuracy: 0.7875
# Epoch 7/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.3666 - accuracy: 0.8828 - val_loss: 0.4432 - val_accuracy: 0.8125
# Epoch 8/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.3147 - accuracy: 0.9141 - val_loss: 0.4255 - val_accuracy: 0.8125
# Epoch 9/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2962 - accuracy: 0.9187 - val_loss: 0.4098 - val_accuracy: 0.8125
# Epoch 10/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2707 - accuracy: 0.9297 - val_loss: 0.3921 - val_accuracy: 0.8313
# Epoch 11/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2398 - accuracy: 0.9406 - val_loss: 0.3767 - val_accuracy: 0.8375
# Epoch 12/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2197 - accuracy: 0.9547 - val_loss: 0.3662 - val_accuracy: 0.8500
# Epoch 13/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1965 - accuracy: 0.9656 - val_loss: 0.3595 - val_accuracy: 0.8625
# Epoch 14/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1771 - accuracy: 0.9641 - val_loss: 0.3435 - val_accuracy: 0.8687
# Epoch 15/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1633 - accuracy: 0.9703 - val_loss: 0.3369 - val_accuracy: 0.8625
# Epoch 16/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1584 - accuracy: 0.9703 - val_loss: 0.3372 - val_accuracy: 0.8687
# Epoch 17/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1284 - accuracy: 0.9781 - val_loss: 0.3286 - val_accuracy: 0.8625
# Epoch 18/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1239 - accuracy: 0.9844 - val_loss: 0.3263 - val_accuracy: 0.8562
# Epoch 19/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0935 - accuracy: 0.9906 - val_loss: 0.3205 - val_accuracy: 0.8562
# Epoch 20/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0776 - accuracy: 0.9953 - val_loss: 0.3222 - val_accuracy: 0.8562
# Epoch 21/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0697 - accuracy: 0.9875 - val_loss: 0.3315 - val_accuracy: 0.8562
# Epoch 22/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0894 - accuracy: 0.9844 - val_loss: 0.3226 - val_accuracy: 0.8562
# Epoch 23/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0631 - accuracy: 0.9953 - val_loss: 0.3071 - val_accuracy: 0.8625
# Epoch 24/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0523 - accuracy: 0.9984 - val_loss: 0.3152 - val_accuracy: 0.8625
# Epoch 25/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0532 - accuracy: 0.9969 - val_loss: 0.3072 - val_accuracy: 0.8625
# ***Performance on Validation data***
# [[79 21]
#  [ 2 98]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.79      0.87       100
#            1       0.82      0.98      0.89       100
#
#     accuracy                           0.89       200
#    macro avg       0.90      0.89      0.88       200
# weighted avg       0.90      0.89      0.88       200
#
#   98
#   79
#  21
#   2
#
# Trial Metrics:
# Sensitivity: 0.98
# Specifity: 0.79
# Precision: 0.8235294117647058
# Score for fold 3: loss of 0.27094799280166626; accuracy of 88.49999904632568%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/25
# 20/20 [==============================] - 53s 1s/step - loss: 0.7706 - accuracy: 0.5359 - val_loss: 0.6442 - val_accuracy: 0.6375
# Epoch 2/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.6829 - accuracy: 0.6141 - val_loss: 0.5945 - val_accuracy: 0.7625
# Epoch 3/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.5955 - accuracy: 0.7078 - val_loss: 0.5501 - val_accuracy: 0.8188
# Epoch 4/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.5408 - accuracy: 0.7281 - val_loss: 0.5128 - val_accuracy: 0.8188
# Epoch 5/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.4999 - accuracy: 0.7609 - val_loss: 0.4777 - val_accuracy: 0.8500
# Epoch 6/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.4599 - accuracy: 0.7703 - val_loss: 0.4427 - val_accuracy: 0.8562
# Epoch 7/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.4248 - accuracy: 0.8031 - val_loss: 0.4160 - val_accuracy: 0.8750
# Epoch 8/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.3944 - accuracy: 0.8250 - val_loss: 0.3992 - val_accuracy: 0.8813
# Epoch 9/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.3545 - accuracy: 0.8656 - val_loss: 0.3805 - val_accuracy: 0.8750
# Epoch 10/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.3255 - accuracy: 0.8953 - val_loss: 0.3658 - val_accuracy: 0.8813
# Epoch 11/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2870 - accuracy: 0.9078 - val_loss: 0.3563 - val_accuracy: 0.8687
# Epoch 12/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2603 - accuracy: 0.9328 - val_loss: 0.3403 - val_accuracy: 0.8750
# Epoch 13/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2376 - accuracy: 0.9375 - val_loss: 0.3282 - val_accuracy: 0.8750
# Epoch 14/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.2318 - accuracy: 0.9438 - val_loss: 0.3229 - val_accuracy: 0.8687
# Epoch 15/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1965 - accuracy: 0.9594 - val_loss: 0.3126 - val_accuracy: 0.8750
# Epoch 16/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.1788 - accuracy: 0.9641 - val_loss: 0.3129 - val_accuracy: 0.8813
# Epoch 17/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1605 - accuracy: 0.9812 - val_loss: 0.3029 - val_accuracy: 0.8813
# Epoch 18/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1341 - accuracy: 0.9844 - val_loss: 0.2940 - val_accuracy: 0.8813
# Epoch 19/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.1193 - accuracy: 0.9859 - val_loss: 0.2966 - val_accuracy: 0.8875
# Epoch 20/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1200 - accuracy: 0.9828 - val_loss: 0.2937 - val_accuracy: 0.8938
# Epoch 21/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0963 - accuracy: 0.9891 - val_loss: 0.2856 - val_accuracy: 0.8938
# Epoch 22/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.1025 - accuracy: 0.9875 - val_loss: 0.2875 - val_accuracy: 0.8875
# Epoch 23/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0742 - accuracy: 0.9969 - val_loss: 0.2880 - val_accuracy: 0.8938
# Epoch 24/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0803 - accuracy: 0.9922 - val_loss: 0.2815 - val_accuracy: 0.8938
# Epoch 25/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0668 - accuracy: 0.9984 - val_loss: 0.2828 - val_accuracy: 0.8875
# ***Performance on Validation data***
# [[80 20]
#  [11 89]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84       100
#            1       0.82      0.89      0.85       100
#
#     accuracy                           0.84       200
#    macro avg       0.85      0.84      0.84       200
# weighted avg       0.85      0.84      0.84       200
#
#   89
#   80
#  20
#   11
#
# Trial Metrics:
# Sensitivity: 0.89
# Specifity: 0.8
# Precision: 0.8165137614678899
# Score for fold 4: loss of 0.3138110637664795; accuracy of 84.50000286102295%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/25
# 20/20 [==============================] - 52s 1s/step - loss: 0.7204 - accuracy: 0.5734 - val_loss: 0.7938 - val_accuracy: 0.4563
# Epoch 2/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.6160 - accuracy: 0.7094 - val_loss: 0.7249 - val_accuracy: 0.6062
# Epoch 3/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.5509 - accuracy: 0.7578 - val_loss: 0.6596 - val_accuracy: 0.6875
# Epoch 4/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.5091 - accuracy: 0.7984 - val_loss: 0.5961 - val_accuracy: 0.7437
# Epoch 5/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.4348 - accuracy: 0.8359 - val_loss: 0.5456 - val_accuracy: 0.7625
# Epoch 6/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.4082 - accuracy: 0.8516 - val_loss: 0.5063 - val_accuracy: 0.8125
# Epoch 7/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.3861 - accuracy: 0.8484 - val_loss: 0.4725 - val_accuracy: 0.8250
# Epoch 8/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.3521 - accuracy: 0.8781 - val_loss: 0.4451 - val_accuracy: 0.8438
# Epoch 9/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.3239 - accuracy: 0.9141 - val_loss: 0.4257 - val_accuracy: 0.8375
# Epoch 10/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.2888 - accuracy: 0.9187 - val_loss: 0.4078 - val_accuracy: 0.8375
# Epoch 11/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.2655 - accuracy: 0.9328 - val_loss: 0.3909 - val_accuracy: 0.8375
# Epoch 12/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2461 - accuracy: 0.9422 - val_loss: 0.3738 - val_accuracy: 0.8438
# Epoch 13/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.2316 - accuracy: 0.9453 - val_loss: 0.3557 - val_accuracy: 0.8500
# Epoch 14/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.2105 - accuracy: 0.9578 - val_loss: 0.3392 - val_accuracy: 0.8625
# Epoch 15/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.1832 - accuracy: 0.9625 - val_loss: 0.3302 - val_accuracy: 0.8625
# Epoch 16/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.1559 - accuracy: 0.9781 - val_loss: 0.3146 - val_accuracy: 0.8687
# Epoch 17/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.1405 - accuracy: 0.9844 - val_loss: 0.3107 - val_accuracy: 0.8625
# Epoch 18/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.1309 - accuracy: 0.9828 - val_loss: 0.3024 - val_accuracy: 0.8875
# Epoch 19/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.1148 - accuracy: 0.9875 - val_loss: 0.2962 - val_accuracy: 0.8938
# Epoch 20/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0980 - accuracy: 0.9937 - val_loss: 0.2953 - val_accuracy: 0.8875
# Epoch 21/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0890 - accuracy: 1.0000 - val_loss: 0.2888 - val_accuracy: 0.8750
# Epoch 22/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0853 - accuracy: 0.9906 - val_loss: 0.2870 - val_accuracy: 0.8813
# Epoch 23/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0764 - accuracy: 0.9969 - val_loss: 0.2886 - val_accuracy: 0.8750
# Epoch 24/25
# 20/20 [==============================] - 24s 1s/step - loss: 0.0665 - accuracy: 0.9984 - val_loss: 0.2753 - val_accuracy: 0.8938
# Epoch 25/25
# 20/20 [==============================] - 25s 1s/step - loss: 0.0629 - accuracy: 0.9969 - val_loss: 0.2723 - val_accuracy: 0.9000
# ***Performance on Validation data***
# [[83 17]
#  [ 7 93]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87       100
#            1       0.85      0.93      0.89       100
#
#     accuracy                           0.88       200
#    macro avg       0.88      0.88      0.88       200
# weighted avg       0.88      0.88      0.88       200
#
#   93
#   83
#  17
#   7
#
# Trial Metrics:
# Sensitivity: 0.93
# Specifity: 0.83
# Precision: 0.8454545454545455
# Score for fold 5: loss of 0.28881266713142395; accuracy of 87.99999952316284%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.3044174313545227 - Accuracy: 87.99999952316284%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.2914942800998688 - Accuracy: 88.49999904632568%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.27094799280166626 - Accuracy: 88.49999904632568%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.3138110637664795 - Accuracy: 84.50000286102295%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.28881266713142395 - Accuracy: 87.99999952316284%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 87.5 (+- 1.516573642491599)
# > Loss: 0.29389668703079225 (+- 0.014598149513668028)
# > Sensitivity: 0.942 (+- 0.034292856398964476)
# > Specifity: 0.808 (+- 0.018330302779823324)
# > Precision: 0.8308963351812786 (+- 0.012159642433835471)
# ------------------------------------------------------------------------
