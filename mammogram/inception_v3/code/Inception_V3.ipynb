# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".jpg":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_train',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_train',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_test',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_test',224))
benign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_validation',224))
malign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_validation',224))
# Out:
# 100%|██████████| 300/300 [00:42<00:00,  7.13it/s]
# 100%|██████████| 300/300 [00:38<00:00,  7.89it/s]
# 100%|██████████| 100/100 [00:16<00:00,  5.89it/s]
# 100%|██████████| 100/100 [00:12<00:00,  8.30it/s]
# 100%|██████████| 100/100 [00:18<00:00,  5.42it/s]
# 100%|██████████| 100/100 [00:14<00:00,  6.80it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('Resized Dimensions : ',benign_train.shape)
print('Resized Dimensions : ',benign_test.shape)
print('Resized Dimensions : ',malign_train.shape)
print('Resized Dimensions : ',malign_test.shape)
print('Resized Dimensions : ',malign_validation.shape)
print('Resized Dimensions : ',malign_validation.shape)
# Out:
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)

# %%
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))
benign_validation_label = np.zeros(len(benign_validation))
malign_validation_label = np.ones(len(malign_validation))

# %%
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)
X_val = np.concatenate((benign_validation, malign_validation),axis=0)
Y_val = np.concatenate((benign_validation_label, malign_validation_label),axis=0)

# %%
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# %%
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
s = np.arange(X_val.shape[0])
np.random.shuffle(s)
X_val = X_val[s]
Y_val = Y_val[s]

# %%
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)
Y_val = to_categorical(Y_val, num_classes= 2)

# %%
# # Display first 15 images , and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
def build_model(backbone, learning_rate=1e-5):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(2, activation='softmax'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=learning_rate),
        metrics=['accuracy']
    )
    
    return model

# %%
K.clear_session()
gc.collect()

inception_v3=tf.keras.applications.InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)


 


model = build_model(inception_v3 ,learning_rate = 1e-5)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  batch_normalization_94 (Bat  (None, 2048)             8192
#  chNormalization)
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 22,073,506
# Trainable params: 22,034,978
# Non-trainable params: 38,528
# _________________________________________________________________

# %%
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=10,verbose=1,factor=0.2, min_lr=1e-7)
early_stopping = EarlyStopping(monitor='val_accuracy', patience=20,verbose=1, mode='max')

# Checkpoint
filepath="memo1.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit(
    X_train,Y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val,Y_val),
    callbacks=[learn_control, checkpoint ,early_stopping],
    shuffle=True
)
# Out:
# Epoch 1/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8142 - accuracy: 0.5150
# Epoch 1: val_accuracy improved from -inf to 0.50500, saving model to memo1.best.hdf5
# 19/19 [==============================] - 43s 1s/step - loss: 0.8142 - accuracy: 0.5150 - val_loss: 0.7283 - val_accuracy: 0.5050 - lr: 1.0000e-05
# Epoch 2/100
# 19/19 [==============================] - ETA: 0s - loss: 0.7117 - accuracy: 0.6200
# Epoch 2: val_accuracy improved from 0.50500 to 0.61000, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 731ms/step - loss: 0.7117 - accuracy: 0.6200 - val_loss: 0.6788 - val_accuracy: 0.6100 - lr: 1.0000e-05
# Epoch 3/100
# 19/19 [==============================] - ETA: 0s - loss: 0.6560 - accuracy: 0.6633
# Epoch 3: val_accuracy improved from 0.61000 to 0.68000, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 727ms/step - loss: 0.6560 - accuracy: 0.6633 - val_loss: 0.6046 - val_accuracy: 0.6800 - lr: 1.0000e-05
# Epoch 4/100
# 19/19 [==============================] - ETA: 0s - loss: 0.5926 - accuracy: 0.7400
# Epoch 4: val_accuracy improved from 0.68000 to 0.79000, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 738ms/step - loss: 0.5926 - accuracy: 0.7400 - val_loss: 0.5327 - val_accuracy: 0.7900 - lr: 1.0000e-05
# Epoch 5/100
# 19/19 [==============================] - ETA: 0s - loss: 0.5319 - accuracy: 0.7833
# Epoch 5: val_accuracy improved from 0.79000 to 0.84000, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 724ms/step - loss: 0.5319 - accuracy: 0.7833 - val_loss: 0.4673 - val_accuracy: 0.8400 - lr: 1.0000e-05
# Epoch 6/100
# 19/19 [==============================] - ETA: 0s - loss: 0.4756 - accuracy: 0.8150
# Epoch 6: val_accuracy improved from 0.84000 to 0.87000, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 727ms/step - loss: 0.4756 - accuracy: 0.8150 - val_loss: 0.4279 - val_accuracy: 0.8700 - lr: 1.0000e-05
# Epoch 7/100
# 19/19 [==============================] - ETA: 0s - loss: 0.4164 - accuracy: 0.8650
# Epoch 7: val_accuracy improved from 0.87000 to 0.88000, saving model to memo1.best.hdf5
# 19/19 [==============================] - 15s 827ms/step - loss: 0.4164 - accuracy: 0.8650 - val_loss: 0.3948 - val_accuracy: 0.8800 - lr: 1.0000e-05
# Epoch 8/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3726 - accuracy: 0.8867
# Epoch 8: val_accuracy improved from 0.88000 to 0.89000, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 727ms/step - loss: 0.3726 - accuracy: 0.8867 - val_loss: 0.3736 - val_accuracy: 0.8900 - lr: 1.0000e-05
# Epoch 9/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3477 - accuracy: 0.9050
# Epoch 9: val_accuracy improved from 0.89000 to 0.90000, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 728ms/step - loss: 0.3477 - accuracy: 0.9050 - val_loss: 0.3609 - val_accuracy: 0.9000 - lr: 1.0000e-05
# Epoch 10/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2954 - accuracy: 0.9133
# Epoch 10: val_accuracy did not improve from 0.90000
# 19/19 [==============================] - 12s 637ms/step - loss: 0.2954 - accuracy: 0.9133 - val_loss: 0.3572 - val_accuracy: 0.8950 - lr: 1.0000e-05
# Epoch 11/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2758 - accuracy: 0.9267
# Epoch 11: val_accuracy did not improve from 0.90000
# 19/19 [==============================] - 12s 642ms/step - loss: 0.2758 - accuracy: 0.9267 - val_loss: 0.3583 - val_accuracy: 0.8950 - lr: 1.0000e-05
# Epoch 12/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.9450
# Epoch 12: val_accuracy did not improve from 0.90000
# 19/19 [==============================] - 12s 641ms/step - loss: 0.2395 - accuracy: 0.9450 - val_loss: 0.3566 - val_accuracy: 0.8850 - lr: 1.0000e-05
# Epoch 13/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1919 - accuracy: 0.9800
# Epoch 13: val_accuracy improved from 0.90000 to 0.90500, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 730ms/step - loss: 0.1919 - accuracy: 0.9800 - val_loss: 0.3343 - val_accuracy: 0.9050 - lr: 1.0000e-05
# Epoch 14/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1863 - accuracy: 0.9667
# Epoch 14: val_accuracy did not improve from 0.90500
# 19/19 [==============================] - 12s 653ms/step - loss: 0.1863 - accuracy: 0.9667 - val_loss: 0.3545 - val_accuracy: 0.8900 - lr: 1.0000e-05
# Epoch 15/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9800
# Epoch 15: val_accuracy did not improve from 0.90500
# 19/19 [==============================] - 12s 643ms/step - loss: 0.1564 - accuracy: 0.9800 - val_loss: 0.3241 - val_accuracy: 0.9000 - lr: 1.0000e-05
# Epoch 16/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9733
# Epoch 16: val_accuracy did not improve from 0.90500
# 19/19 [==============================] - 12s 643ms/step - loss: 0.1424 - accuracy: 0.9733 - val_loss: 0.3266 - val_accuracy: 0.9000 - lr: 1.0000e-05
# Epoch 17/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1117 - accuracy: 0.9900
# Epoch 17: val_accuracy did not improve from 0.90500
# 19/19 [==============================] - 12s 647ms/step - loss: 0.1117 - accuracy: 0.9900 - val_loss: 0.3295 - val_accuracy: 0.9050 - lr: 1.0000e-05
# Epoch 18/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9817
# Epoch 18: val_accuracy did not improve from 0.90500
# 19/19 [==============================] - 12s 646ms/step - loss: 0.1157 - accuracy: 0.9817 - val_loss: 0.3277 - val_accuracy: 0.9050 - lr: 1.0000e-05
# Epoch 19/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9900
# Epoch 19: val_accuracy did not improve from 0.90500
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0884 - accuracy: 0.9900 - val_loss: 0.3409 - val_accuracy: 0.9050 - lr: 1.0000e-05
# Epoch 20/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.90500
# 19/19 [==============================] - 12s 646ms/step - loss: 0.0701 - accuracy: 1.0000 - val_loss: 0.3297 - val_accuracy: 0.9050 - lr: 1.0000e-05
# Epoch 21/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0762 - accuracy: 0.9950
# Epoch 21: val_accuracy improved from 0.90500 to 0.91000, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 732ms/step - loss: 0.0762 - accuracy: 0.9950 - val_loss: 0.3317 - val_accuracy: 0.9100 - lr: 1.0000e-05
# Epoch 22/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9983
# Epoch 22: val_accuracy improved from 0.91000 to 0.91500, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 731ms/step - loss: 0.0662 - accuracy: 0.9983 - val_loss: 0.3233 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 23/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.91500
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0536 - accuracy: 1.0000 - val_loss: 0.3144 - val_accuracy: 0.9100 - lr: 1.0000e-05
# Epoch 24/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9917
# Epoch 24: val_accuracy did not improve from 0.91500
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0618 - accuracy: 0.9917 - val_loss: 0.3202 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 25/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9983
# Epoch 25: val_accuracy did not improve from 0.91500
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0500 - accuracy: 0.9983 - val_loss: 0.3319 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 26/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.91500
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0454 - accuracy: 1.0000 - val_loss: 0.3227 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 27/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9967
# Epoch 27: val_accuracy did not improve from 0.91500
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0465 - accuracy: 0.9967 - val_loss: 0.3033 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 28/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.91500
# 19/19 [==============================] - 12s 646ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.3011 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 29/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.91500
# 19/19 [==============================] - 12s 648ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.2906 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 30/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.91500
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.2967 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 31/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 1.0000
# Epoch 31: val_accuracy improved from 0.91500 to 0.92500, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 731ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.3130 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 32/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9983
# Epoch 32: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 644ms/step - loss: 0.0335 - accuracy: 0.9983 - val_loss: 0.3081 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 33/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.3033 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 34/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0318 - accuracy: 0.9983
# Epoch 34: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0318 - accuracy: 0.9983 - val_loss: 0.3058 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 35/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9967
# Epoch 35: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0247 - accuracy: 0.9967 - val_loss: 0.2966 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 36/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9983
# Epoch 36: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 644ms/step - loss: 0.0191 - accuracy: 0.9983 - val_loss: 0.2877 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 37/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9983
# Epoch 37: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0198 - accuracy: 0.9983 - val_loss: 0.2945 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 38/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 644ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.2905 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 39/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.3043 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 40/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.3066 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 41/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
#
# Epoch 41: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 648ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.3080 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 42/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.3069 - val_accuracy: 0.9200 - lr: 2.0000e-06
# Epoch 43/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 646ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.3054 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 44/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 655ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.3044 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 45/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9967
# Epoch 45: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 646ms/step - loss: 0.0246 - accuracy: 0.9967 - val_loss: 0.3031 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 46/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.3014 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 47/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 658ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.3014 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 48/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.2995 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 49/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 12s 659ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2955 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 50/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 1.0000
# Epoch 50: val_accuracy improved from 0.92500 to 0.93000, saving model to memo1.best.hdf5
# 19/19 [==============================] - 14s 732ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.2927 - val_accuracy: 0.9300 - lr: 2.0000e-06
# Epoch 51/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.2956 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 52/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.3003 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 53/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.3039 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 54/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 54: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.3050 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 55/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 648ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.3033 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 56/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 646ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.3017 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 57/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9983
# Epoch 57: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 658ms/step - loss: 0.0162 - accuracy: 0.9983 - val_loss: 0.3037 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 58/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9983
# Epoch 58: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0150 - accuracy: 0.9983 - val_loss: 0.3056 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 59/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.3036 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 60/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
#
# Epoch 60: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.3021 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 61/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 646ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.3025 - val_accuracy: 0.9250 - lr: 4.0000e-07
# Epoch 62/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 644ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.3026 - val_accuracy: 0.9250 - lr: 4.0000e-07
# Epoch 63/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 647ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.3004 - val_accuracy: 0.9250 - lr: 4.0000e-07
# Epoch 64/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 1.0000
# Epoch 64: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 646ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2989 - val_accuracy: 0.9250 - lr: 4.0000e-07
# Epoch 65/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9967
# Epoch 65: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 649ms/step - loss: 0.0141 - accuracy: 0.9967 - val_loss: 0.2972 - val_accuracy: 0.9250 - lr: 4.0000e-07
# Epoch 66/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 1.0000
# Epoch 66: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 646ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.2989 - val_accuracy: 0.9250 - lr: 4.0000e-07
# Epoch 67/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9983
# Epoch 67: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 656ms/step - loss: 0.0179 - accuracy: 0.9983 - val_loss: 0.3006 - val_accuracy: 0.9250 - lr: 4.0000e-07
# Epoch 68/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 1.0000
# Epoch 68: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 648ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.2999 - val_accuracy: 0.9250 - lr: 4.0000e-07
# Epoch 69/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 1.0000
# Epoch 69: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 648ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.3006 - val_accuracy: 0.9250 - lr: 4.0000e-07
# Epoch 70/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 70: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 12s 645ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.3013 - val_accuracy: 0.9250 - lr: 4.0000e-07
# Epoch 70: early stopping

# %%
model.load_weights("memo1.best.hdf5")

# %%
Y_val_pred = model.predict(X_val)

# %%
accuracy_score(np.argmax(Y_val, axis=1), np.argmax(Y_val_pred, axis=1))
# Out:
# 0.93

# %%
train_loss_fe = history.history['loss']
train_acc_fe = history.history['accuracy']
val_loss_fe = history.history['val_loss']
val_acc_fe = history.history['val_accuracy']

epochs_fe = range(1, len(train_acc_fe)+1)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_fe, train_acc_fe, label='Training Accuracy')
plt.plot(epochs_fe, val_acc_fe, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_fe,train_loss_fe , label='Training Loss')
plt.plot(epochs_fe, val_loss_fe, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from time import sleep
import time
start = time.process_time() 
Y_pred = model.predict(X_test)
end = time.process_time()
print("Time per image: {} ".format((end-start)/len(X_test)))
# Out:
# Time per image: 0.005792296110000166

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for breast cancer')
# Out:
# Confusion matrix, without normalization
# [[75 25]
#  [17 83]]

# %%
from sklearn.metrics import classification_report
print(classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.78       100
#            1       0.77      0.83      0.80       100
#
#     accuracy                           0.79       200
#    macro avg       0.79      0.79      0.79       200
# weighted avg       0.79      0.79      0.79       200

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

plt.close()
