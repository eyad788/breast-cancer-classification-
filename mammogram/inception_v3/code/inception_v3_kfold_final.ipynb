# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".jpg":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_train',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_train',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_test',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_test',224))
benign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_validation',224))
malign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_validation',224))
# Out:
# 100%|██████████| 300/300 [00:48<00:00,  6.15it/s]
# 100%|██████████| 300/300 [00:37<00:00,  7.95it/s]
# 100%|██████████| 100/100 [00:16<00:00,  5.90it/s]
# 100%|██████████| 100/100 [00:12<00:00,  8.22it/s]
# 100%|██████████| 100/100 [00:18<00:00,  5.31it/s]
# 100%|██████████| 100/100 [00:14<00:00,  6.85it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('Resized Dimensions : ',benign_train.shape)
print('Resized Dimensions : ',benign_test.shape)
print('Resized Dimensions : ',malign_train.shape)
print('Resized Dimensions : ',malign_test.shape)
print('Resized Dimensions : ',malign_validation.shape)
print('Resized Dimensions : ',malign_validation.shape)
# Out:
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)

# %%
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))
benign_validation_label = np.zeros(len(benign_validation))
malign_validation_label = np.ones(len(malign_validation))

# %%
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)
X_val = np.concatenate((benign_validation, malign_validation),axis=0)
Y_val = np.concatenate((benign_validation_label, malign_validation_label),axis=0)

# %%
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# %%
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
s = np.arange(X_val.shape[0])
np.random.shuffle(s)
X_val = X_val[s]
Y_val = Y_val[s]

# %%
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)
Y_val = to_categorical(Y_val, num_classes= 2)

# %%
acc_per_fold = []
loss_per_fold = []
sens_per_fold = []
spec_per_fold = []  
prec_per_fold = []

# %%
inputs = np.concatenate((X_train, X_val), axis=0)
targets = np.concatenate((Y_train, Y_val), axis=0)

# %%
# # Display first 15 images , and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(targets[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(inputs[i], interpolation='nearest')
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications.inception_v3 import InceptionV3
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
kfold = KFold(n_splits=5, shuffle=True)

# K-fold Cross Validation model evaluation

fold_no = 1
for train, test in kfold.split(inputs, targets):
    
    
    def build_model(backbone, learning_rate=1e-5):
        
        model = Sequential()
        model.add(backbone)
        model.add(layers.GlobalAveragePooling2D())
        model.add(layers.Dropout(0.5))
        model.add(layers.BatchNormalization())
        model.add(Dense(128, activation='relu'))
        model.add(layers.Dense(2, activation='softmax'))
        
    
    
        model.compile(loss='binary_crossentropy',optimizer=Adam(learning_rate=learning_rate),metrics=['accuracy'])
    
        return model


    inception_v3 = tf.keras.applications.InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3))


 
    model = build_model(inception_v3 ,learning_rate = 1e-5)
    
    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    history = model.fit(
    inputs[train], targets[train],
    epochs=25,
    batch_size=32,
    validation_data=(inputs[test],targets[test]),
    shuffle=True
    )
    
    predictions = model.predict(X_test)
    true_classes = Y_test
    # evaluate validation performance
    print("***Performance on Validation data***")    
    cm = confusion_matrix(np.argmax(true_classes, axis=1), np.argmax(predictions, axis=1))
    print(cm)
    print(classification_report( np.argmax(true_classes, axis=1), np.argmax(predictions, axis=1)))

    TP = cm[1,1] # true positive 
    TN = cm[0,0] # true negative
    FN = cm[1,0] # false negative
    FP = cm[0,1] # false positive
    print(f"  {TP}\n  {TN}\n {FP}\n  {FN}\n ")
    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP/(TP+FN)
    # Specificity or true negative rate
    TNR = TN/(TN+FP) 
    # Precision or positive predictive value
    PPV = TP/(TP+FP)
    # Negative predictive value
    NPV = TN/(TN+FN)
    # Fall out or false positive rate
    FPR = FP/(FP+TN)
    # False negative rate
    FNR = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP)



    print(f"Trial Metrics:")
    print(f"Sensitivity: {TPR}\nSpecifity: {TNR}\nPrecision: {PPV} ")
    

    scores = model.evaluate(X_test, Y_test, verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%' )
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])
    sens_per_fold.append(TPR) 
    spec_per_fold.append(TNR)  
    prec_per_fold.append(PPV) 
   
    

    fold_no = fold_no + 1


# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)} (+- {np.std(loss_per_fold)})')
print(f'> Sensitivity: {np.mean(sens_per_fold)} (+- {np.std(sens_per_fold)})')
print(f'> Specifity: {np.mean(spec_per_fold)} (+- {np.std(spec_per_fold)})')
print(f'> Precision: {np.mean(prec_per_fold)} (+- {np.std(prec_per_fold)})')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/25
# 20/20 [==============================] - 23s 710ms/step - loss: 0.9126 - accuracy: 0.4953 - val_loss: 0.8504 - val_accuracy: 0.5188
# Epoch 2/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.7987 - accuracy: 0.5516 - val_loss: 0.8781 - val_accuracy: 0.5188
# Epoch 3/25
# 20/20 [==============================] - 12s 614ms/step - loss: 0.6905 - accuracy: 0.6266 - val_loss: 0.9027 - val_accuracy: 0.5188
# Epoch 4/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.6342 - accuracy: 0.6656 - val_loss: 0.8839 - val_accuracy: 0.5375
# Epoch 5/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.5358 - accuracy: 0.7406 - val_loss: 0.8716 - val_accuracy: 0.5813
# Epoch 6/25
# 20/20 [==============================] - 12s 613ms/step - loss: 0.4479 - accuracy: 0.8094 - val_loss: 0.8293 - val_accuracy: 0.6187
# Epoch 7/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.4013 - accuracy: 0.8328 - val_loss: 0.7896 - val_accuracy: 0.6625
# Epoch 8/25
# 20/20 [==============================] - 12s 614ms/step - loss: 0.3418 - accuracy: 0.8734 - val_loss: 0.7354 - val_accuracy: 0.6687
# Epoch 9/25
# 20/20 [==============================] - 12s 613ms/step - loss: 0.2923 - accuracy: 0.9000 - val_loss: 0.6677 - val_accuracy: 0.7375
# Epoch 10/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.2222 - accuracy: 0.9578 - val_loss: 0.6153 - val_accuracy: 0.7688
# Epoch 11/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.2164 - accuracy: 0.9531 - val_loss: 0.5505 - val_accuracy: 0.7812
# Epoch 12/25
# 20/20 [==============================] - 12s 589ms/step - loss: 0.1611 - accuracy: 0.9719 - val_loss: 0.5218 - val_accuracy: 0.7812
# Epoch 13/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.1424 - accuracy: 0.9797 - val_loss: 0.4947 - val_accuracy: 0.7937
# Epoch 14/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.1239 - accuracy: 0.9828 - val_loss: 0.4553 - val_accuracy: 0.7937
# Epoch 15/25
# 20/20 [==============================] - 12s 613ms/step - loss: 0.1029 - accuracy: 0.9891 - val_loss: 0.4565 - val_accuracy: 0.8062
# Epoch 16/25
# 20/20 [==============================] - 12s 614ms/step - loss: 0.0787 - accuracy: 0.9953 - val_loss: 0.4449 - val_accuracy: 0.8188
# Epoch 17/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0601 - accuracy: 0.9969 - val_loss: 0.4463 - val_accuracy: 0.8250
# Epoch 18/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.0557 - accuracy: 0.9969 - val_loss: 0.4509 - val_accuracy: 0.8375
# Epoch 19/25
# 20/20 [==============================] - 12s 613ms/step - loss: 0.0519 - accuracy: 0.9984 - val_loss: 0.4427 - val_accuracy: 0.8313
# Epoch 20/25
# 20/20 [==============================] - 12s 585ms/step - loss: 0.0506 - accuracy: 0.9969 - val_loss: 0.4583 - val_accuracy: 0.8313
# Epoch 21/25
# 20/20 [==============================] - 12s 585ms/step - loss: 0.0496 - accuracy: 0.9937 - val_loss: 0.4663 - val_accuracy: 0.8313
# Epoch 22/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0419 - accuracy: 0.9984 - val_loss: 0.4544 - val_accuracy: 0.8313
# Epoch 23/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.0345 - accuracy: 0.9984 - val_loss: 0.4438 - val_accuracy: 0.8313
# Epoch 24/25
# 20/20 [==============================] - 12s 613ms/step - loss: 0.0287 - accuracy: 0.9984 - val_loss: 0.4405 - val_accuracy: 0.8313
# Epoch 25/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.4391 - val_accuracy: 0.8375
# ***Performance on Validation data***
# [[82 18]
#  [16 84]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       100
#            1       0.82      0.84      0.83       100
#
#     accuracy                           0.83       200
#    macro avg       0.83      0.83      0.83       200
# weighted avg       0.83      0.83      0.83       200
#
#   84
#   82
#  18
#   16
#
# Trial Metrics:
# Sensitivity: 0.84
# Specifity: 0.82
# Precision: 0.8235294117647058
# Score for fold 1: loss of 0.39339983463287354; accuracy of 82.99999833106995%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/25
# 20/20 [==============================] - 23s 694ms/step - loss: 0.8064 - accuracy: 0.5516 - val_loss: 0.7957 - val_accuracy: 0.4375
# Epoch 2/25
# 20/20 [==============================] - 12s 590ms/step - loss: 0.6537 - accuracy: 0.6875 - val_loss: 0.7396 - val_accuracy: 0.4938
# Epoch 3/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.6059 - accuracy: 0.7109 - val_loss: 0.7106 - val_accuracy: 0.5688
# Epoch 4/25
# 20/20 [==============================] - 12s 616ms/step - loss: 0.5429 - accuracy: 0.7625 - val_loss: 0.6342 - val_accuracy: 0.6625
# Epoch 5/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.4606 - accuracy: 0.8250 - val_loss: 0.5846 - val_accuracy: 0.7063
# Epoch 6/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.3945 - accuracy: 0.8687 - val_loss: 0.5454 - val_accuracy: 0.7500
# Epoch 7/25
# 20/20 [==============================] - 12s 613ms/step - loss: 0.3526 - accuracy: 0.8891 - val_loss: 0.5157 - val_accuracy: 0.7875
# Epoch 8/25
# 20/20 [==============================] - 12s 615ms/step - loss: 0.3116 - accuracy: 0.9109 - val_loss: 0.4925 - val_accuracy: 0.7563
# Epoch 9/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.2924 - accuracy: 0.9172 - val_loss: 0.4846 - val_accuracy: 0.7688
# Epoch 10/25
# 20/20 [==============================] - 12s 616ms/step - loss: 0.2476 - accuracy: 0.9422 - val_loss: 0.4639 - val_accuracy: 0.7937
# Epoch 11/25
# 20/20 [==============================] - 12s 614ms/step - loss: 0.2097 - accuracy: 0.9516 - val_loss: 0.4542 - val_accuracy: 0.7875
# Epoch 12/25
# 20/20 [==============================] - 12s 589ms/step - loss: 0.1743 - accuracy: 0.9719 - val_loss: 0.4359 - val_accuracy: 0.8000
# Epoch 13/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.1526 - accuracy: 0.9750 - val_loss: 0.4181 - val_accuracy: 0.8125
# Epoch 14/25
# 20/20 [==============================] - 12s 616ms/step - loss: 0.1234 - accuracy: 0.9875 - val_loss: 0.4104 - val_accuracy: 0.8313
# Epoch 15/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.1081 - accuracy: 0.9953 - val_loss: 0.4041 - val_accuracy: 0.8438
# Epoch 16/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.1026 - accuracy: 0.9922 - val_loss: 0.3948 - val_accuracy: 0.8625
# Epoch 17/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0879 - accuracy: 0.9953 - val_loss: 0.3912 - val_accuracy: 0.8500
# Epoch 18/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.0595 - accuracy: 0.9984 - val_loss: 0.3865 - val_accuracy: 0.8438
# Epoch 19/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0682 - accuracy: 0.9937 - val_loss: 0.3860 - val_accuracy: 0.8438
# Epoch 20/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.0750 - accuracy: 0.9891 - val_loss: 0.3931 - val_accuracy: 0.8500
# Epoch 21/25
# 20/20 [==============================] - 12s 614ms/step - loss: 0.0465 - accuracy: 0.9984 - val_loss: 0.3837 - val_accuracy: 0.8500
# Epoch 22/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.0409 - accuracy: 1.0000 - val_loss: 0.3916 - val_accuracy: 0.8438
# Epoch 23/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0539 - accuracy: 0.9953 - val_loss: 0.3967 - val_accuracy: 0.8375
# Epoch 24/25
# 20/20 [==============================] - 12s 616ms/step - loss: 0.0343 - accuracy: 0.9984 - val_loss: 0.3954 - val_accuracy: 0.8375
# Epoch 25/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0456 - accuracy: 0.9969 - val_loss: 0.3975 - val_accuracy: 0.8500
# ***Performance on Validation data***
# [[77 23]
#  [12 88]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.77      0.81       100
#            1       0.79      0.88      0.83       100
#
#     accuracy                           0.82       200
#    macro avg       0.83      0.82      0.82       200
# weighted avg       0.83      0.82      0.82       200
#
#   88
#   77
#  23
#   12
#
# Trial Metrics:
# Sensitivity: 0.88
# Specifity: 0.77
# Precision: 0.7927927927927928
# Score for fold 2: loss of 0.42760512232780457; accuracy of 82.4999988079071%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/25
# 20/20 [==============================] - 22s 671ms/step - loss: 0.9082 - accuracy: 0.5406 - val_loss: 0.7560 - val_accuracy: 0.4500
# Epoch 2/25
# 20/20 [==============================] - 12s 589ms/step - loss: 0.7818 - accuracy: 0.6219 - val_loss: 0.7090 - val_accuracy: 0.5188
# Epoch 3/25
# 20/20 [==============================] - 12s 589ms/step - loss: 0.7243 - accuracy: 0.6703 - val_loss: 0.6969 - val_accuracy: 0.6125
# Epoch 4/25
# 20/20 [==============================] - 12s 617ms/step - loss: 0.6236 - accuracy: 0.7437 - val_loss: 0.7031 - val_accuracy: 0.6250
# Epoch 5/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.5789 - accuracy: 0.7625 - val_loss: 0.6586 - val_accuracy: 0.6687
# Epoch 6/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.5044 - accuracy: 0.7891 - val_loss: 0.6220 - val_accuracy: 0.6687
# Epoch 7/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.4582 - accuracy: 0.8250 - val_loss: 0.6060 - val_accuracy: 0.7000
# Epoch 8/25
# 20/20 [==============================] - 12s 589ms/step - loss: 0.4141 - accuracy: 0.8562 - val_loss: 0.6024 - val_accuracy: 0.7000
# Epoch 9/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.3501 - accuracy: 0.8891 - val_loss: 0.5847 - val_accuracy: 0.7188
# Epoch 10/25
# 20/20 [==============================] - 12s 614ms/step - loss: 0.3164 - accuracy: 0.9062 - val_loss: 0.5386 - val_accuracy: 0.7375
# Epoch 11/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.2797 - accuracy: 0.9172 - val_loss: 0.5329 - val_accuracy: 0.7312
# Epoch 12/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.2449 - accuracy: 0.9422 - val_loss: 0.5032 - val_accuracy: 0.7375
# Epoch 13/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.1945 - accuracy: 0.9672 - val_loss: 0.4886 - val_accuracy: 0.7563
# Epoch 14/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.1701 - accuracy: 0.9766 - val_loss: 0.4889 - val_accuracy: 0.7750
# Epoch 15/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.1442 - accuracy: 0.9719 - val_loss: 0.4747 - val_accuracy: 0.7688
# Epoch 16/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.1261 - accuracy: 0.9828 - val_loss: 0.4894 - val_accuracy: 0.7688
# Epoch 17/25
# 20/20 [==============================] - 12s 613ms/step - loss: 0.1264 - accuracy: 0.9828 - val_loss: 0.4596 - val_accuracy: 0.7812
# Epoch 18/25
# 20/20 [==============================] - 12s 615ms/step - loss: 0.0923 - accuracy: 0.9937 - val_loss: 0.4349 - val_accuracy: 0.7937
# Epoch 19/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0854 - accuracy: 0.9937 - val_loss: 0.4207 - val_accuracy: 0.8000
# Epoch 20/25
# 20/20 [==============================] - 12s 615ms/step - loss: 0.0663 - accuracy: 0.9969 - val_loss: 0.4055 - val_accuracy: 0.8062
# Epoch 21/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.0744 - accuracy: 0.9937 - val_loss: 0.4103 - val_accuracy: 0.7937
# Epoch 22/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0562 - accuracy: 0.9969 - val_loss: 0.4105 - val_accuracy: 0.7875
# Epoch 23/25
# 20/20 [==============================] - 12s 613ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.4121 - val_accuracy: 0.7937
# Epoch 24/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0476 - accuracy: 0.9969 - val_loss: 0.4188 - val_accuracy: 0.7875
# Epoch 25/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.0351 - accuracy: 0.9984 - val_loss: 0.4018 - val_accuracy: 0.8062
# ***Performance on Validation data***
# [[73 27]
#  [ 6 94]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.82       100
#            1       0.78      0.94      0.85       100
#
#     accuracy                           0.83       200
#    macro avg       0.85      0.83      0.83       200
# weighted avg       0.85      0.83      0.83       200
#
#   94
#   73
#  27
#   6
#
# Trial Metrics:
# Sensitivity: 0.94
# Specifity: 0.73
# Precision: 0.7768595041322314
# Score for fold 3: loss of 0.3830038011074066; accuracy of 83.49999785423279%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/25
# 20/20 [==============================] - 22s 696ms/step - loss: 0.7821 - accuracy: 0.5547 - val_loss: 0.7361 - val_accuracy: 0.5625
# Epoch 2/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.6740 - accuracy: 0.6734 - val_loss: 0.7894 - val_accuracy: 0.5188
# Epoch 3/25
# 20/20 [==============================] - 12s 616ms/step - loss: 0.5943 - accuracy: 0.7594 - val_loss: 0.7230 - val_accuracy: 0.5750
# Epoch 4/25
# 20/20 [==============================] - 12s 616ms/step - loss: 0.5163 - accuracy: 0.7984 - val_loss: 0.6392 - val_accuracy: 0.6438
# Epoch 5/25
# 20/20 [==============================] - 12s 616ms/step - loss: 0.4396 - accuracy: 0.8516 - val_loss: 0.6137 - val_accuracy: 0.6938
# Epoch 6/25
# 20/20 [==============================] - 12s 590ms/step - loss: 0.3999 - accuracy: 0.8766 - val_loss: 0.5788 - val_accuracy: 0.7250
# Epoch 7/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.3475 - accuracy: 0.8938 - val_loss: 0.5398 - val_accuracy: 0.7688
# Epoch 8/25
# 20/20 [==============================] - 12s 616ms/step - loss: 0.3155 - accuracy: 0.9078 - val_loss: 0.5305 - val_accuracy: 0.7812
# Epoch 9/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.2606 - accuracy: 0.9281 - val_loss: 0.5288 - val_accuracy: 0.7812
# Epoch 10/25
# 20/20 [==============================] - 12s 615ms/step - loss: 0.2188 - accuracy: 0.9500 - val_loss: 0.5197 - val_accuracy: 0.7875
# Epoch 11/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.1862 - accuracy: 0.9719 - val_loss: 0.4903 - val_accuracy: 0.8000
# Epoch 12/25
# 20/20 [==============================] - 12s 616ms/step - loss: 0.1516 - accuracy: 0.9766 - val_loss: 0.4901 - val_accuracy: 0.7937
# Epoch 13/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.1234 - accuracy: 0.9906 - val_loss: 0.4850 - val_accuracy: 0.7812
# Epoch 14/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.1202 - accuracy: 0.9828 - val_loss: 0.4665 - val_accuracy: 0.8062
# Epoch 15/25
# 20/20 [==============================] - 12s 613ms/step - loss: 0.1024 - accuracy: 0.9828 - val_loss: 0.4619 - val_accuracy: 0.8000
# Epoch 16/25
# 20/20 [==============================] - 12s 614ms/step - loss: 0.0663 - accuracy: 0.9984 - val_loss: 0.4508 - val_accuracy: 0.8313
# Epoch 17/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.0696 - accuracy: 0.9937 - val_loss: 0.4449 - val_accuracy: 0.8125
# Epoch 18/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.0597 - accuracy: 0.9984 - val_loss: 0.4386 - val_accuracy: 0.8250
# Epoch 19/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0491 - accuracy: 1.0000 - val_loss: 0.4388 - val_accuracy: 0.8188
# Epoch 20/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.4413 - val_accuracy: 0.8188
# Epoch 21/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.0350 - accuracy: 0.9984 - val_loss: 0.4453 - val_accuracy: 0.8062
# Epoch 22/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.0397 - accuracy: 0.9953 - val_loss: 0.4504 - val_accuracy: 0.8062
# Epoch 23/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0359 - accuracy: 0.9969 - val_loss: 0.4559 - val_accuracy: 0.8125
# Epoch 24/25
# 20/20 [==============================] - 12s 615ms/step - loss: 0.0297 - accuracy: 0.9953 - val_loss: 0.4484 - val_accuracy: 0.8125
# Epoch 25/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.4534 - val_accuracy: 0.8125
# ***Performance on Validation data***
# [[74 26]
#  [ 8 92]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.74      0.81       100
#            1       0.78      0.92      0.84       100
#
#     accuracy                           0.83       200
#    macro avg       0.84      0.83      0.83       200
# weighted avg       0.84      0.83      0.83       200
#
#   92
#   74
#  26
#   8
#
# Trial Metrics:
# Sensitivity: 0.92
# Specifity: 0.74
# Precision: 0.7796610169491526
# Score for fold 4: loss of 0.36536213755607605; accuracy of 82.99999833106995%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/25
# 20/20 [==============================] - 22s 698ms/step - loss: 1.1067 - accuracy: 0.5328 - val_loss: 0.8532 - val_accuracy: 0.4688
# Epoch 2/25
# 20/20 [==============================] - 12s 589ms/step - loss: 0.9905 - accuracy: 0.6297 - val_loss: 0.8111 - val_accuracy: 0.5688
# Epoch 3/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.8746 - accuracy: 0.6891 - val_loss: 0.7743 - val_accuracy: 0.5312
# Epoch 4/25
# 20/20 [==============================] - 12s 591ms/step - loss: 0.8012 - accuracy: 0.7328 - val_loss: 0.7180 - val_accuracy: 0.6313
# Epoch 5/25
# 20/20 [==============================] - 12s 616ms/step - loss: 0.7109 - accuracy: 0.7766 - val_loss: 0.6424 - val_accuracy: 0.6562
# Epoch 6/25
# 20/20 [==============================] - 12s 590ms/step - loss: 0.6596 - accuracy: 0.7891 - val_loss: 0.5797 - val_accuracy: 0.7125
# Epoch 7/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.6025 - accuracy: 0.8203 - val_loss: 0.5460 - val_accuracy: 0.7188
# Epoch 8/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.5097 - accuracy: 0.8453 - val_loss: 0.5112 - val_accuracy: 0.7375
# Epoch 9/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.4658 - accuracy: 0.8641 - val_loss: 0.4868 - val_accuracy: 0.7812
# Epoch 10/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.3956 - accuracy: 0.8844 - val_loss: 0.4675 - val_accuracy: 0.8000
# Epoch 11/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.3231 - accuracy: 0.9203 - val_loss: 0.4496 - val_accuracy: 0.8062
# Epoch 12/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.2913 - accuracy: 0.9391 - val_loss: 0.4350 - val_accuracy: 0.8188
# Epoch 13/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.2354 - accuracy: 0.9547 - val_loss: 0.4281 - val_accuracy: 0.8125
# Epoch 14/25
# 20/20 [==============================] - 12s 589ms/step - loss: 0.2100 - accuracy: 0.9578 - val_loss: 0.4226 - val_accuracy: 0.8188
# Epoch 15/25
# 20/20 [==============================] - 12s 614ms/step - loss: 0.1893 - accuracy: 0.9688 - val_loss: 0.4121 - val_accuracy: 0.8250
# Epoch 16/25
# 20/20 [==============================] - 12s 588ms/step - loss: 0.1433 - accuracy: 0.9797 - val_loss: 0.4097 - val_accuracy: 0.8125
# Epoch 17/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.1355 - accuracy: 0.9781 - val_loss: 0.3957 - val_accuracy: 0.8438
# Epoch 18/25
# 20/20 [==============================] - 12s 615ms/step - loss: 0.1050 - accuracy: 0.9828 - val_loss: 0.3861 - val_accuracy: 0.8438
# Epoch 19/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0985 - accuracy: 0.9922 - val_loss: 0.3964 - val_accuracy: 0.8375
# Epoch 20/25
# 20/20 [==============================] - 12s 587ms/step - loss: 0.0745 - accuracy: 0.9937 - val_loss: 0.4061 - val_accuracy: 0.8375
# Epoch 21/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0594 - accuracy: 0.9953 - val_loss: 0.4045 - val_accuracy: 0.8375
# Epoch 22/25
# 20/20 [==============================] - 12s 615ms/step - loss: 0.0446 - accuracy: 1.0000 - val_loss: 0.4003 - val_accuracy: 0.8438
# Epoch 23/25
# 20/20 [==============================] - 12s 613ms/step - loss: 0.0516 - accuracy: 0.9937 - val_loss: 0.3988 - val_accuracy: 0.8500
# Epoch 24/25
# 20/20 [==============================] - 12s 586ms/step - loss: 0.0483 - accuracy: 0.9984 - val_loss: 0.3945 - val_accuracy: 0.8438
# Epoch 25/25
# 20/20 [==============================] - 12s 614ms/step - loss: 0.0473 - accuracy: 0.9953 - val_loss: 0.3914 - val_accuracy: 0.8438
# ***Performance on Validation data***
# [[77 23]
#  [ 6 94]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84       100
#            1       0.80      0.94      0.87       100
#
#     accuracy                           0.85       200
#    macro avg       0.87      0.85      0.85       200
# weighted avg       0.87      0.85      0.85       200
#
#   94
#   77
#  23
#   6
#
# Trial Metrics:
# Sensitivity: 0.94
# Specifity: 0.77
# Precision: 0.8034188034188035
# Score for fold 5: loss of 0.36360976099967957; accuracy of 85.50000190734863%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.39339983463287354 - Accuracy: 82.99999833106995%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.42760512232780457 - Accuracy: 82.4999988079071%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.3830038011074066 - Accuracy: 83.49999785423279%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.36536213755607605 - Accuracy: 82.99999833106995%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.36360976099967957 - Accuracy: 85.50000190734863%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 83.49999904632568 (+- 1.048810121180294)
# > Loss: 0.38659613132476806 (+- 0.023324614767551394)
# > Sensitivity: 0.9039999999999999 (+- 0.03878143885933062)
# > Specifity: 0.7659999999999999 (+- 0.031368774282716234)
# > Precision: 0.7952523058115373 (+- 0.017051211397142305)
# ------------------------------------------------------------------------
