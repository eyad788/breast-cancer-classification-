# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".jpg":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_train',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_train',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_test',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_test',224))
benign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_validation',224))
malign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_validation',224))
# Out:
# 100%|██████████| 300/300 [00:42<00:00,  7.13it/s]
# 100%|██████████| 300/300 [00:38<00:00,  7.89it/s]
# 100%|██████████| 100/100 [00:16<00:00,  5.89it/s]
# 100%|██████████| 100/100 [00:12<00:00,  8.30it/s]
# 100%|██████████| 100/100 [00:18<00:00,  5.42it/s]
# 100%|██████████| 100/100 [00:14<00:00,  6.80it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('Resized Dimensions : ',benign_train.shape)
print('Resized Dimensions : ',benign_test.shape)
print('Resized Dimensions : ',malign_train.shape)
print('Resized Dimensions : ',malign_test.shape)
print('Resized Dimensions : ',malign_validation.shape)
print('Resized Dimensions : ',malign_validation.shape)
# Out:
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)

# %%
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))
benign_validation_label = np.zeros(len(benign_validation))
malign_validation_label = np.ones(len(malign_validation))

# %%
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)
X_val = np.concatenate((benign_validation, malign_validation),axis=0)
Y_val = np.concatenate((benign_validation_label, malign_validation_label),axis=0)

# %%
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# %%
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
s = np.arange(X_val.shape[0])
np.random.shuffle(s)
X_val = X_val[s]
Y_val = Y_val[s]

# %%
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)
Y_val = to_categorical(Y_val, num_classes= 2)

# %%
# # Display first 15 images , and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
def build_model(backbone, learning_rate=1e-5):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(2, activation='softmax'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=learning_rate),
        metrics=['accuracy']
    )
    
    return model

# %%
K.clear_session()
gc.collect()

vgg = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

 


model = build_model(vgg ,learning_rate = 1e-5)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dense (Dense)               (None, 256)               131328
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 14,848,578
# Trainable params: 14,847,554
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=10,verbose=1,factor=0.2, min_lr=1e-7)
early_stopping = EarlyStopping(monitor='val_accuracy', patience=20,verbose=1, mode='max')

# Checkpoint
filepath="memo3.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit(
    X_train,Y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val,Y_val),
    callbacks=[learn_control, checkpoint ,early_stopping],
    shuffle=True
)
# Out:
# Epoch 1/100
# 19/19 [==============================] - ETA: 0s - loss: 0.7704 - accuracy: 0.5483
# Epoch 1: val_accuracy improved from -inf to 0.50500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 23s 1s/step - loss: 0.7704 - accuracy: 0.5483 - val_loss: 0.7711 - val_accuracy: 0.5050 - lr: 1.0000e-05
# Epoch 2/100
# 19/19 [==============================] - ETA: 0s - loss: 0.6537 - accuracy: 0.6367
# Epoch 2: val_accuracy improved from 0.50500 to 0.57500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.6537 - accuracy: 0.6367 - val_loss: 0.5964 - val_accuracy: 0.5750 - lr: 1.0000e-05
# Epoch 3/100
# 19/19 [==============================] - ETA: 0s - loss: 0.5839 - accuracy: 0.7100
# Epoch 3: val_accuracy improved from 0.57500 to 0.66500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.5839 - accuracy: 0.7100 - val_loss: 0.4905 - val_accuracy: 0.6650 - lr: 1.0000e-05
# Epoch 4/100
# 19/19 [==============================] - ETA: 0s - loss: 0.5435 - accuracy: 0.7533
# Epoch 4: val_accuracy improved from 0.66500 to 0.77000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.5435 - accuracy: 0.7533 - val_loss: 0.4412 - val_accuracy: 0.7700 - lr: 1.0000e-05
# Epoch 5/100
# 19/19 [==============================] - ETA: 0s - loss: 0.5040 - accuracy: 0.7683
# Epoch 5: val_accuracy did not improve from 0.77000
# 19/19 [==============================] - 19s 989ms/step - loss: 0.5040 - accuracy: 0.7683 - val_loss: 0.4777 - val_accuracy: 0.7250 - lr: 1.0000e-05
# Epoch 6/100
# 19/19 [==============================] - ETA: 0s - loss: 0.4546 - accuracy: 0.8317
# Epoch 6: val_accuracy improved from 0.77000 to 0.81500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.4546 - accuracy: 0.8317 - val_loss: 0.4029 - val_accuracy: 0.8150 - lr: 1.0000e-05
# Epoch 7/100
# 19/19 [==============================] - ETA: 0s - loss: 0.4317 - accuracy: 0.8517
# Epoch 7: val_accuracy did not improve from 0.81500
# 19/19 [==============================] - 19s 989ms/step - loss: 0.4317 - accuracy: 0.8517 - val_loss: 0.4086 - val_accuracy: 0.8150 - lr: 1.0000e-05
# Epoch 8/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3913 - accuracy: 0.8683
# Epoch 8: val_accuracy improved from 0.81500 to 0.85000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.3913 - accuracy: 0.8683 - val_loss: 0.3956 - val_accuracy: 0.8500 - lr: 1.0000e-05
# Epoch 9/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3771 - accuracy: 0.8733
# Epoch 9: val_accuracy improved from 0.85000 to 0.85500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.3771 - accuracy: 0.8733 - val_loss: 0.3887 - val_accuracy: 0.8550 - lr: 1.0000e-05
# Epoch 10/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3382 - accuracy: 0.9017
# Epoch 10: val_accuracy improved from 0.85500 to 0.86000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.3382 - accuracy: 0.9017 - val_loss: 0.3907 - val_accuracy: 0.8600 - lr: 1.0000e-05
# Epoch 11/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 0.9150
# Epoch 11: val_accuracy did not improve from 0.86000
# 19/19 [==============================] - 19s 989ms/step - loss: 0.3305 - accuracy: 0.9150 - val_loss: 0.3850 - val_accuracy: 0.8600 - lr: 1.0000e-05
# Epoch 12/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3098 - accuracy: 0.9167
# Epoch 12: val_accuracy improved from 0.86000 to 0.88000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.3098 - accuracy: 0.9167 - val_loss: 0.3566 - val_accuracy: 0.8800 - lr: 1.0000e-05
# Epoch 13/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.9133
# Epoch 13: val_accuracy did not improve from 0.88000
# 19/19 [==============================] - 19s 987ms/step - loss: 0.3060 - accuracy: 0.9133 - val_loss: 0.3624 - val_accuracy: 0.8800 - lr: 1.0000e-05
# Epoch 14/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2605 - accuracy: 0.9517
# Epoch 14: val_accuracy did not improve from 0.88000
# 19/19 [==============================] - 19s 987ms/step - loss: 0.2605 - accuracy: 0.9517 - val_loss: 0.3611 - val_accuracy: 0.8800 - lr: 1.0000e-05
# Epoch 15/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2541 - accuracy: 0.9450
# Epoch 15: val_accuracy did not improve from 0.88000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.2541 - accuracy: 0.9450 - val_loss: 0.3573 - val_accuracy: 0.8800 - lr: 1.0000e-05
# Epoch 16/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9700
# Epoch 16: val_accuracy improved from 0.88000 to 0.90000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.2219 - accuracy: 0.9700 - val_loss: 0.3257 - val_accuracy: 0.9000 - lr: 1.0000e-05
# Epoch 17/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.9500
# Epoch 17: val_accuracy improved from 0.90000 to 0.92000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.2227 - accuracy: 0.9500 - val_loss: 0.2993 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 18/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2081 - accuracy: 0.9667
# Epoch 18: val_accuracy did not improve from 0.92000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.2081 - accuracy: 0.9667 - val_loss: 0.3298 - val_accuracy: 0.8850 - lr: 1.0000e-05
# Epoch 19/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9767
# Epoch 19: val_accuracy did not improve from 0.92000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.1889 - accuracy: 0.9767 - val_loss: 0.3419 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Epoch 20/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1852 - accuracy: 0.9733
# Epoch 20: val_accuracy improved from 0.92000 to 0.93500, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.1852 - accuracy: 0.9733 - val_loss: 0.2730 - val_accuracy: 0.9350 - lr: 1.0000e-05
# Epoch 21/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1741 - accuracy: 0.9833
# Epoch 21: val_accuracy did not improve from 0.93500
# 19/19 [==============================] - 19s 989ms/step - loss: 0.1741 - accuracy: 0.9833 - val_loss: 0.2794 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 22/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9817
# Epoch 22: val_accuracy did not improve from 0.93500
# 19/19 [==============================] - 19s 989ms/step - loss: 0.1593 - accuracy: 0.9817 - val_loss: 0.3374 - val_accuracy: 0.8800 - lr: 1.0000e-05
# Epoch 23/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1452 - accuracy: 0.9883
# Epoch 23: val_accuracy did not improve from 0.93500
# 19/19 [==============================] - 19s 988ms/step - loss: 0.1452 - accuracy: 0.9883 - val_loss: 0.2693 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 24/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1338 - accuracy: 0.9917
# Epoch 24: val_accuracy did not improve from 0.93500
# 19/19 [==============================] - 19s 989ms/step - loss: 0.1338 - accuracy: 0.9917 - val_loss: 0.2672 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 25/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9933
# Epoch 25: val_accuracy did not improve from 0.93500
# 19/19 [==============================] - 19s 988ms/step - loss: 0.1265 - accuracy: 0.9933 - val_loss: 0.2862 - val_accuracy: 0.9050 - lr: 1.0000e-05
# Epoch 26/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1277 - accuracy: 0.9933
# Epoch 26: val_accuracy did not improve from 0.93500
# 19/19 [==============================] - 19s 988ms/step - loss: 0.1277 - accuracy: 0.9933 - val_loss: 0.2899 - val_accuracy: 0.9050 - lr: 1.0000e-05
# Epoch 27/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1097 - accuracy: 0.9917
# Epoch 27: val_accuracy did not improve from 0.93500
# 19/19 [==============================] - 19s 988ms/step - loss: 0.1097 - accuracy: 0.9917 - val_loss: 0.2756 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 28/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1030 - accuracy: 0.9933
# Epoch 28: val_accuracy did not improve from 0.93500
# 19/19 [==============================] - 19s 988ms/step - loss: 0.1030 - accuracy: 0.9933 - val_loss: 0.2616 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 29/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9983
# Epoch 29: val_accuracy did not improve from 0.93500
# 19/19 [==============================] - 19s 987ms/step - loss: 0.0956 - accuracy: 0.9983 - val_loss: 0.2923 - val_accuracy: 0.8950 - lr: 1.0000e-05
# Epoch 30/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9950
# Epoch 30: val_accuracy improved from 0.93500 to 0.95000, saving model to memo3.best.hdf5
# 19/19 [==============================] - 19s 1s/step - loss: 0.0975 - accuracy: 0.9950 - val_loss: 0.2362 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 31/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0954 - accuracy: 0.9933
# Epoch 31: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.0954 - accuracy: 0.9933 - val_loss: 0.2681 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 32/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0929 - accuracy: 0.9917
# Epoch 32: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.0929 - accuracy: 0.9917 - val_loss: 0.3419 - val_accuracy: 0.8900 - lr: 1.0000e-05
# Epoch 33/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9983
# Epoch 33: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.0781 - accuracy: 0.9983 - val_loss: 0.2550 - val_accuracy: 0.9300 - lr: 1.0000e-05
# Epoch 34/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.0727 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 35/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 987ms/step - loss: 0.0695 - accuracy: 1.0000 - val_loss: 0.2639 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 36/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9983
# Epoch 36: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 989ms/step - loss: 0.0617 - accuracy: 0.9983 - val_loss: 0.2372 - val_accuracy: 0.9400 - lr: 1.0000e-05
# Epoch 37/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9967
# Epoch 37: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.0662 - accuracy: 0.9967 - val_loss: 0.2370 - val_accuracy: 0.9350 - lr: 1.0000e-05
# Epoch 38/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9900
# Epoch 38: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 990ms/step - loss: 0.0643 - accuracy: 0.9900 - val_loss: 0.2516 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 39/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 991ms/step - loss: 0.0583 - accuracy: 1.0000 - val_loss: 0.2423 - val_accuracy: 0.9350 - lr: 1.0000e-05
# Epoch 40/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 1.0000
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
#
# Epoch 40: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 989ms/step - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.2264 - val_accuracy: 0.9400 - lr: 1.0000e-05
# Epoch 41/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 989ms/step - loss: 0.0469 - accuracy: 1.0000 - val_loss: 0.2464 - val_accuracy: 0.9350 - lr: 2.0000e-06
# Epoch 42/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 987ms/step - loss: 0.0497 - accuracy: 1.0000 - val_loss: 0.2550 - val_accuracy: 0.9300 - lr: 2.0000e-06
# Epoch 43/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 989ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 0.2508 - val_accuracy: 0.9300 - lr: 2.0000e-06
# Epoch 44/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.0425 - accuracy: 1.0000 - val_loss: 0.2596 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 45/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.0459 - accuracy: 1.0000 - val_loss: 0.2522 - val_accuracy: 0.9300 - lr: 2.0000e-06
# Epoch 46/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.0402 - accuracy: 1.0000 - val_loss: 0.2549 - val_accuracy: 0.9250 - lr: 2.0000e-06
# Epoch 47/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 1s/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.2442 - val_accuracy: 0.9350 - lr: 2.0000e-06
# Epoch 48/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 989ms/step - loss: 0.0383 - accuracy: 1.0000 - val_loss: 0.2441 - val_accuracy: 0.9350 - lr: 2.0000e-06
# Epoch 49/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 988ms/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.2485 - val_accuracy: 0.9350 - lr: 2.0000e-06
# Epoch 50/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 1.0000
# Epoch 50: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
#
# Epoch 50: val_accuracy did not improve from 0.95000
# 19/19 [==============================] - 19s 989ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.2488 - val_accuracy: 0.9300 - lr: 2.0000e-06
# Epoch 50: early stopping

# %%
model.load_weights("memo3.best.hdf5")

# %%
Y_val_pred = model.predict(X_val)

# %%
accuracy_score(np.argmax(Y_val, axis=1), np.argmax(Y_val_pred, axis=1))
# Out:
# 0.95

# %%
train_loss_fe = history.history['loss']
train_acc_fe = history.history['accuracy']
val_loss_fe = history.history['val_loss']
val_acc_fe = history.history['val_accuracy']

epochs_fe = range(1, len(train_acc_fe)+1)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_fe, train_acc_fe, label='Training Accuracy')
plt.plot(epochs_fe, val_acc_fe, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_fe,train_loss_fe , label='Training Loss')
plt.plot(epochs_fe, val_loss_fe, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from time import sleep
import time
start = time.process_time() 
Y_pred = model.predict(X_test)
end = time.process_time()
print("Time per image: {} ".format((end-start)/len(X_test)))
# Out:
# Time per image: 0.00977335840500018

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for breast cancer')
# Out:
# Confusion matrix, without normalization
# [[78 22]
#  [14 86]]

# %%
from sklearn.metrics import classification_report
print(classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81       100
#            1       0.80      0.86      0.83       100
#
#     accuracy                           0.82       200
#    macro avg       0.82      0.82      0.82       200
# weighted avg       0.82      0.82      0.82       200

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

plt.close()
