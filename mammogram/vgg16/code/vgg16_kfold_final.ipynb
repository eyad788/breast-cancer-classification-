# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".jpg":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_train',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_train',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_test',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_test',224))
benign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_validation',224))
malign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_validation',224))
# Out:
# 100%|██████████| 300/300 [00:43<00:00,  6.94it/s]
# 100%|██████████| 300/300 [00:37<00:00,  7.96it/s]
# 100%|██████████| 100/100 [00:16<00:00,  5.91it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.59it/s]
# 100%|██████████| 100/100 [00:18<00:00,  5.42it/s]
# 100%|██████████| 100/100 [00:14<00:00,  6.86it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('Resized Dimensions : ',benign_train.shape)
print('Resized Dimensions : ',benign_test.shape)
print('Resized Dimensions : ',malign_train.shape)
print('Resized Dimensions : ',malign_test.shape)
print('Resized Dimensions : ',malign_validation.shape)
print('Resized Dimensions : ',malign_validation.shape)
# Out:
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)

# %%
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))
benign_validation_label = np.zeros(len(benign_validation))
malign_validation_label = np.ones(len(malign_validation))

# %%
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)
X_val = np.concatenate((benign_validation, malign_validation),axis=0)
Y_val = np.concatenate((benign_validation_label, malign_validation_label),axis=0)

# %%
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# %%
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
s = np.arange(X_val.shape[0])
np.random.shuffle(s)
X_val = X_val[s]
Y_val = Y_val[s]

# %%
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)
Y_val = to_categorical(Y_val, num_classes= 2)

# %%
acc_per_fold = []
loss_per_fold = []
sens_per_fold = [] 
spec_per_fold = []
prec_per_fold = []

# %%
inputs = np.concatenate((X_train, X_val), axis=0)
targets = np.concatenate((Y_train, Y_val), axis=0)

# %%
# # Display first 15 images , and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(targets[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(inputs[i], interpolation='nearest')
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications.inception_v3 import InceptionV3
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
kfold = KFold(n_splits=5, shuffle=True)

# K-fold Cross Validation model evaluation

fold_no = 1
for train, test in kfold.split(inputs, targets):
    
    
    def build_model(backbone, learning_rate=1e-5):
        
        model = Sequential()
        model.add(backbone)
        model.add(layers.GlobalAveragePooling2D())
        model.add(layers.Dropout(0.5))
        model.add(layers.BatchNormalization())
        model.add(Dense(256, activation='relu'))
        model.add(layers.Dense(2, activation='softmax'))
        
    
    
        model.compile(loss='binary_crossentropy',optimizer=Adam(learning_rate=learning_rate),metrics=['accuracy'])
    
        return model


    vgg = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3))


 
    model = build_model(vgg ,learning_rate = 1e-5)
    
    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    history = model.fit(
    inputs[train], targets[train],
    epochs=25,
    batch_size=32,
    validation_data=(inputs[test],targets[test]),
    shuffle=True
    )
    
    predictions = model.predict(X_test)
    true_classes = Y_test
    # evaluate validation performance
    print("**Performance on Validation data**")    
    cm = confusion_matrix(np.argmax(true_classes, axis=1), np.argmax(predictions, axis=1))
    print(cm)
    print(classification_report( np.argmax(true_classes, axis=1), np.argmax(predictions, axis=1)))

    TP = cm[1,1] # true positive 
    TN = cm[0,0] # true negative
    FN = cm[1,0] # false negative
    FP = cm[0,1] # false positive
    print(f"  {TP}\n  {TN}\n {FP}\n  {FN}\n ")
    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP/(TP+FN)
    # Specificity or true negative rate
    TNR = TN/(TN+FP) 
    # Precision or positive predictive value
    PPV = TP/(TP+FP)
    # Negative predictive value
    NPV = TN/(TN+FN)
    # Fall out or false positive rate
    FPR = FP/(FP+TN)
    # False negative rate
    FNR = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP)



    print(f"Trial Metrics:")
    print(f"Sensitivity: {TPR}\nSpecifity: {TNR}\nPrecision: {PPV} ")
    

    scores = model.evaluate(X_test, Y_test, verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%' )
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])
    sens_per_fold.append(TPR) 
    spec_per_fold.append(TNR)  
    prec_per_fold.append(PPV) 
   
    

    fold_no = fold_no + 1


# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)} (+- {np.std(loss_per_fold)})')
print(f'> Sensitivity: {np.mean(sens_per_fold)} (+- {np.std(sens_per_fold)})')
print(f'> Specifity: {np.mean(spec_per_fold)} (+- {np.std(spec_per_fold)})')
print(f'> Precision: {np.mean(prec_per_fold)} (+- {np.std(prec_per_fold)})')
print('------------------------------------------------------------------------')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/25
# 20/20 [==============================] - 38s 934ms/step - loss: 0.7274 - accuracy: 0.6109 - val_loss: 0.6308 - val_accuracy: 0.6250
# Epoch 2/25
# 20/20 [==============================] - 20s 986ms/step - loss: 0.5920 - accuracy: 0.7266 - val_loss: 0.5383 - val_accuracy: 0.7250
# Epoch 3/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.5547 - accuracy: 0.7375 - val_loss: 0.5102 - val_accuracy: 0.7437
# Epoch 4/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.4778 - accuracy: 0.8109 - val_loss: 0.4884 - val_accuracy: 0.7750
# Epoch 5/25
# 20/20 [==============================] - 19s 982ms/step - loss: 0.4300 - accuracy: 0.8391 - val_loss: 0.4701 - val_accuracy: 0.7875
# Epoch 6/25
# 20/20 [==============================] - 20s 982ms/step - loss: 0.3996 - accuracy: 0.8687 - val_loss: 0.4535 - val_accuracy: 0.8062
# Epoch 7/25
# 20/20 [==============================] - 20s 985ms/step - loss: 0.3740 - accuracy: 0.8766 - val_loss: 0.4331 - val_accuracy: 0.8000
# Epoch 8/25
# 20/20 [==============================] - 20s 982ms/step - loss: 0.3349 - accuracy: 0.9125 - val_loss: 0.4104 - val_accuracy: 0.8062
# Epoch 9/25
# 20/20 [==============================] - 18s 920ms/step - loss: 0.3108 - accuracy: 0.9266 - val_loss: 0.3921 - val_accuracy: 0.8125
# Epoch 10/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.2900 - accuracy: 0.9234 - val_loss: 0.3935 - val_accuracy: 0.8313
# Epoch 11/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.2686 - accuracy: 0.9312 - val_loss: 0.3843 - val_accuracy: 0.8188
# Epoch 12/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.2603 - accuracy: 0.9422 - val_loss: 0.3812 - val_accuracy: 0.8062
# Epoch 13/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.2435 - accuracy: 0.9422 - val_loss: 0.3734 - val_accuracy: 0.8062
# Epoch 14/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.2278 - accuracy: 0.9422 - val_loss: 0.3641 - val_accuracy: 0.8375
# Epoch 15/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.2069 - accuracy: 0.9547 - val_loss: 0.3607 - val_accuracy: 0.8313
# Epoch 16/25
# 20/20 [==============================] - 19s 981ms/step - loss: 0.1896 - accuracy: 0.9656 - val_loss: 0.3688 - val_accuracy: 0.8375
# Epoch 17/25
# 20/20 [==============================] - 18s 920ms/step - loss: 0.1784 - accuracy: 0.9656 - val_loss: 0.3555 - val_accuracy: 0.8375
# Epoch 18/25
# 20/20 [==============================] - 20s 984ms/step - loss: 0.1724 - accuracy: 0.9672 - val_loss: 0.3502 - val_accuracy: 0.8500
# Epoch 19/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.1463 - accuracy: 0.9781 - val_loss: 0.3619 - val_accuracy: 0.8438
# Epoch 20/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.1544 - accuracy: 0.9750 - val_loss: 0.3392 - val_accuracy: 0.8313
# Epoch 21/25
# 20/20 [==============================] - 19s 982ms/step - loss: 0.1360 - accuracy: 0.9781 - val_loss: 0.3444 - val_accuracy: 0.8438
# Epoch 22/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.1320 - accuracy: 0.9797 - val_loss: 0.3472 - val_accuracy: 0.8438
# Epoch 23/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.1255 - accuracy: 0.9797 - val_loss: 0.3376 - val_accuracy: 0.8438
# Epoch 24/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.1093 - accuracy: 0.9875 - val_loss: 0.3346 - val_accuracy: 0.8562
# Epoch 25/25
# 20/20 [==============================] - 19s 981ms/step - loss: 0.1032 - accuracy: 0.9891 - val_loss: 0.3374 - val_accuracy: 0.8625
# **Performance on Validation data**
# [[74 26]
#  [ 1 99]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.74      0.85       100
#            1       0.79      0.99      0.88       100
#
#     accuracy                           0.86       200
#    macro avg       0.89      0.86      0.86       200
# weighted avg       0.89      0.86      0.86       200
#
#   99
#   74
#  26
#   1
#
# Trial Metrics:
# Sensitivity: 0.99
# Specifity: 0.74
# Precision: 0.792
# Score for fold 1: loss of 0.30973127484321594; accuracy of 86.50000095367432%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/25
# 20/20 [==============================] - 20s 936ms/step - loss: 0.7954 - accuracy: 0.5172 - val_loss: 0.7612 - val_accuracy: 0.5625
# Epoch 2/25
# 20/20 [==============================] - 20s 982ms/step - loss: 0.6586 - accuracy: 0.6578 - val_loss: 0.6325 - val_accuracy: 0.7000
# Epoch 3/25
# 20/20 [==============================] - 18s 920ms/step - loss: 0.5829 - accuracy: 0.7156 - val_loss: 0.5497 - val_accuracy: 0.7125
# Epoch 4/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.5025 - accuracy: 0.7781 - val_loss: 0.5037 - val_accuracy: 0.7500
# Epoch 5/25
# 20/20 [==============================] - 20s 984ms/step - loss: 0.4821 - accuracy: 0.7781 - val_loss: 0.4816 - val_accuracy: 0.7375
# Epoch 6/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.4304 - accuracy: 0.8125 - val_loss: 0.4523 - val_accuracy: 0.7750
# Epoch 7/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.4070 - accuracy: 0.8344 - val_loss: 0.4489 - val_accuracy: 0.7875
# Epoch 8/25
# 20/20 [==============================] - 20s 984ms/step - loss: 0.3722 - accuracy: 0.8578 - val_loss: 0.4232 - val_accuracy: 0.8125
# Epoch 9/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.3559 - accuracy: 0.8562 - val_loss: 0.4209 - val_accuracy: 0.8062
# Epoch 10/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.3322 - accuracy: 0.8859 - val_loss: 0.4060 - val_accuracy: 0.8125
# Epoch 11/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.2957 - accuracy: 0.9016 - val_loss: 0.3996 - val_accuracy: 0.8062
# Epoch 12/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.2841 - accuracy: 0.9062 - val_loss: 0.3876 - val_accuracy: 0.8188
# Epoch 13/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.2454 - accuracy: 0.9312 - val_loss: 0.4002 - val_accuracy: 0.8125
# Epoch 14/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.2306 - accuracy: 0.9469 - val_loss: 0.3897 - val_accuracy: 0.8125
# Epoch 15/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.2272 - accuracy: 0.9469 - val_loss: 0.3592 - val_accuracy: 0.8562
# Epoch 16/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.2298 - accuracy: 0.9406 - val_loss: 0.3636 - val_accuracy: 0.8375
# Epoch 17/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.1998 - accuracy: 0.9531 - val_loss: 0.3547 - val_accuracy: 0.8562
# Epoch 18/25
# 20/20 [==============================] - 20s 982ms/step - loss: 0.1822 - accuracy: 0.9781 - val_loss: 0.3552 - val_accuracy: 0.8375
# Epoch 19/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.1750 - accuracy: 0.9734 - val_loss: 0.3389 - val_accuracy: 0.8813
# Epoch 20/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.1726 - accuracy: 0.9641 - val_loss: 0.3492 - val_accuracy: 0.8438
# Epoch 21/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.1511 - accuracy: 0.9750 - val_loss: 0.3243 - val_accuracy: 0.8750
# Epoch 22/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.1397 - accuracy: 0.9844 - val_loss: 0.3267 - val_accuracy: 0.8875
# Epoch 23/25
# 20/20 [==============================] - 20s 982ms/step - loss: 0.1346 - accuracy: 0.9812 - val_loss: 0.3311 - val_accuracy: 0.8625
# Epoch 24/25
# 20/20 [==============================] - 20s 984ms/step - loss: 0.1234 - accuracy: 0.9875 - val_loss: 0.3213 - val_accuracy: 0.8813
# Epoch 25/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.1097 - accuracy: 0.9891 - val_loss: 0.3110 - val_accuracy: 0.8813
# **Performance on Validation data**
# [[81 19]
#  [ 9 91]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85       100
#            1       0.83      0.91      0.87       100
#
#     accuracy                           0.86       200
#    macro avg       0.86      0.86      0.86       200
# weighted avg       0.86      0.86      0.86       200
#
#   91
#   81
#  19
#   9
#
# Trial Metrics:
# Sensitivity: 0.91
# Specifity: 0.81
# Precision: 0.8272727272727273
# Score for fold 2: loss of 0.37607502937316895; accuracy of 86.00000143051147%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/25
# 20/20 [==============================] - 20s 939ms/step - loss: 0.7737 - accuracy: 0.5234 - val_loss: 0.6645 - val_accuracy: 0.6500
# Epoch 2/25
# 20/20 [==============================] - 20s 986ms/step - loss: 0.6280 - accuracy: 0.6750 - val_loss: 0.5565 - val_accuracy: 0.7375
# Epoch 3/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.5120 - accuracy: 0.7906 - val_loss: 0.4979 - val_accuracy: 0.8000
# Epoch 4/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.4637 - accuracy: 0.8234 - val_loss: 0.4675 - val_accuracy: 0.8062
# Epoch 5/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.4172 - accuracy: 0.8422 - val_loss: 0.4512 - val_accuracy: 0.8562
# Epoch 6/25
# 20/20 [==============================] - 20s 985ms/step - loss: 0.3832 - accuracy: 0.8578 - val_loss: 0.4305 - val_accuracy: 0.8562
# Epoch 7/25
# 20/20 [==============================] - 20s 984ms/step - loss: 0.3615 - accuracy: 0.8859 - val_loss: 0.4045 - val_accuracy: 0.8375
# Epoch 8/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.3133 - accuracy: 0.9062 - val_loss: 0.4085 - val_accuracy: 0.8375
# Epoch 9/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.2931 - accuracy: 0.9187 - val_loss: 0.3876 - val_accuracy: 0.8500
# Epoch 10/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.2800 - accuracy: 0.9172 - val_loss: 0.3878 - val_accuracy: 0.8438
# Epoch 11/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.2622 - accuracy: 0.9312 - val_loss: 0.3597 - val_accuracy: 0.8562
# Epoch 12/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.2478 - accuracy: 0.9391 - val_loss: 0.3576 - val_accuracy: 0.8687
# Epoch 13/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.2439 - accuracy: 0.9406 - val_loss: 0.3448 - val_accuracy: 0.8625
# Epoch 14/25
# 20/20 [==============================] - 18s 925ms/step - loss: 0.2148 - accuracy: 0.9469 - val_loss: 0.3439 - val_accuracy: 0.8750
# Epoch 15/25
# 20/20 [==============================] - 20s 985ms/step - loss: 0.2003 - accuracy: 0.9594 - val_loss: 0.3438 - val_accuracy: 0.8625
# Epoch 16/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.1847 - accuracy: 0.9672 - val_loss: 0.3314 - val_accuracy: 0.8687
# Epoch 17/25
# 20/20 [==============================] - 20s 985ms/step - loss: 0.1831 - accuracy: 0.9578 - val_loss: 0.3193 - val_accuracy: 0.8687
# Epoch 18/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.1692 - accuracy: 0.9766 - val_loss: 0.3119 - val_accuracy: 0.8750
# Epoch 19/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.1532 - accuracy: 0.9766 - val_loss: 0.3053 - val_accuracy: 0.8813
# Epoch 20/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.1404 - accuracy: 0.9875 - val_loss: 0.3035 - val_accuracy: 0.8687
# Epoch 21/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.1363 - accuracy: 0.9844 - val_loss: 0.3046 - val_accuracy: 0.8813
# Epoch 22/25
# 20/20 [==============================] - 20s 986ms/step - loss: 0.1256 - accuracy: 0.9844 - val_loss: 0.2917 - val_accuracy: 0.8875
# Epoch 23/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.1130 - accuracy: 0.9891 - val_loss: 0.2884 - val_accuracy: 0.8875
# Epoch 24/25
# 20/20 [==============================] - 20s 984ms/step - loss: 0.1177 - accuracy: 0.9875 - val_loss: 0.2838 - val_accuracy: 0.8813
# Epoch 25/25
# 20/20 [==============================] - 20s 986ms/step - loss: 0.0957 - accuracy: 0.9953 - val_loss: 0.2752 - val_accuracy: 0.8875
# **Performance on Validation data**
# [[73 27]
#  [10 90]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.73      0.80       100
#            1       0.77      0.90      0.83       100
#
#     accuracy                           0.81       200
#    macro avg       0.82      0.81      0.81       200
# weighted avg       0.82      0.81      0.81       200
#
#   90
#   73
#  27
#   10
#
# Trial Metrics:
# Sensitivity: 0.9
# Specifity: 0.73
# Precision: 0.7692307692307693
# Score for fold 3: loss of 0.3648098111152649; accuracy of 81.49999976158142%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/25
# 20/20 [==============================] - 21s 1000ms/step - loss: 0.7821 - accuracy: 0.5391 - val_loss: 0.6980 - val_accuracy: 0.5312
# Epoch 2/25
# 20/20 [==============================] - 20s 986ms/step - loss: 0.6604 - accuracy: 0.6625 - val_loss: 0.5843 - val_accuracy: 0.5750
# Epoch 3/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.5754 - accuracy: 0.7531 - val_loss: 0.5198 - val_accuracy: 0.7000
# Epoch 4/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.5180 - accuracy: 0.7937 - val_loss: 0.4720 - val_accuracy: 0.8313
# Epoch 5/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.4598 - accuracy: 0.8484 - val_loss: 0.4339 - val_accuracy: 0.8562
# Epoch 6/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.4331 - accuracy: 0.8375 - val_loss: 0.4256 - val_accuracy: 0.8500
# Epoch 7/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.4046 - accuracy: 0.8719 - val_loss: 0.3876 - val_accuracy: 0.8750
# Epoch 8/25
# 20/20 [==============================] - 20s 984ms/step - loss: 0.3746 - accuracy: 0.8672 - val_loss: 0.3801 - val_accuracy: 0.8687
# Epoch 9/25
# 20/20 [==============================] - 19s 981ms/step - loss: 0.3424 - accuracy: 0.9031 - val_loss: 0.3683 - val_accuracy: 0.8750
# Epoch 10/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.3270 - accuracy: 0.9000 - val_loss: 0.3795 - val_accuracy: 0.8625
# Epoch 11/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.3059 - accuracy: 0.9031 - val_loss: 0.3625 - val_accuracy: 0.8375
# Epoch 12/25
# 20/20 [==============================] - 20s 984ms/step - loss: 0.2733 - accuracy: 0.9328 - val_loss: 0.3488 - val_accuracy: 0.8813
# Epoch 13/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.2700 - accuracy: 0.9219 - val_loss: 0.3430 - val_accuracy: 0.8625
# Epoch 14/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.2511 - accuracy: 0.9250 - val_loss: 0.3320 - val_accuracy: 0.8875
# Epoch 15/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.2204 - accuracy: 0.9563 - val_loss: 0.3249 - val_accuracy: 0.8875
# Epoch 16/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.2168 - accuracy: 0.9469 - val_loss: 0.3323 - val_accuracy: 0.8625
# Epoch 17/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.2018 - accuracy: 0.9563 - val_loss: 0.2915 - val_accuracy: 0.9000
# Epoch 18/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.1884 - accuracy: 0.9656 - val_loss: 0.3151 - val_accuracy: 0.9000
# Epoch 19/25
# 20/20 [==============================] - 20s 985ms/step - loss: 0.1727 - accuracy: 0.9656 - val_loss: 0.3253 - val_accuracy: 0.8562
# Epoch 20/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.1692 - accuracy: 0.9688 - val_loss: 0.2891 - val_accuracy: 0.9000
# Epoch 21/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.1425 - accuracy: 0.9875 - val_loss: 0.2973 - val_accuracy: 0.8875
# Epoch 22/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.1416 - accuracy: 0.9734 - val_loss: 0.3050 - val_accuracy: 0.8750
# Epoch 23/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.1205 - accuracy: 0.9859 - val_loss: 0.2843 - val_accuracy: 0.8938
# Epoch 24/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.1195 - accuracy: 0.9859 - val_loss: 0.2568 - val_accuracy: 0.9000
# Epoch 25/25
# 20/20 [==============================] - 18s 921ms/step - loss: 0.1063 - accuracy: 0.9906 - val_loss: 0.2782 - val_accuracy: 0.9000
# **Performance on Validation data**
# [[ 75  25]
#  [  0 100]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86       100
#            1       0.80      1.00      0.89       100
#
#     accuracy                           0.88       200
#    macro avg       0.90      0.88      0.87       200
# weighted avg       0.90      0.88      0.87       200
#
#   100
#   75
#  25
#   0
#
# Trial Metrics:
# Sensitivity: 1.0
# Specifity: 0.75
# Precision: 0.8
# Score for fold 4: loss of 0.3383306562900543; accuracy of 87.5%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/25
# 20/20 [==============================] - 21s 1s/step - loss: 0.7460 - accuracy: 0.5688 - val_loss: 0.6588 - val_accuracy: 0.6375
# Epoch 2/25
# 20/20 [==============================] - 18s 925ms/step - loss: 0.6424 - accuracy: 0.6734 - val_loss: 0.5573 - val_accuracy: 0.7437
# Epoch 3/25
# 20/20 [==============================] - 18s 926ms/step - loss: 0.5630 - accuracy: 0.7625 - val_loss: 0.5057 - val_accuracy: 0.7937
# Epoch 4/25
# 20/20 [==============================] - 18s 926ms/step - loss: 0.5133 - accuracy: 0.7859 - val_loss: 0.4824 - val_accuracy: 0.8062
# Epoch 5/25
# 20/20 [==============================] - 20s 982ms/step - loss: 0.4759 - accuracy: 0.8000 - val_loss: 0.4512 - val_accuracy: 0.8188
# Epoch 6/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.4322 - accuracy: 0.8281 - val_loss: 0.4501 - val_accuracy: 0.8062
# Epoch 7/25
# 20/20 [==============================] - 20s 984ms/step - loss: 0.4020 - accuracy: 0.8578 - val_loss: 0.4129 - val_accuracy: 0.8188
# Epoch 8/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.3869 - accuracy: 0.8453 - val_loss: 0.4151 - val_accuracy: 0.8375
# Epoch 9/25
# 20/20 [==============================] - 20s 985ms/step - loss: 0.3531 - accuracy: 0.8797 - val_loss: 0.3928 - val_accuracy: 0.8562
# Epoch 10/25
# 20/20 [==============================] - 18s 923ms/step - loss: 0.3304 - accuracy: 0.8906 - val_loss: 0.3593 - val_accuracy: 0.8500
# Epoch 11/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.3072 - accuracy: 0.9094 - val_loss: 0.3680 - val_accuracy: 0.8750
# Epoch 12/25
# 20/20 [==============================] - 18s 925ms/step - loss: 0.2988 - accuracy: 0.9125 - val_loss: 0.3452 - val_accuracy: 0.8750
# Epoch 13/25
# 20/20 [==============================] - 20s 985ms/step - loss: 0.2855 - accuracy: 0.9234 - val_loss: 0.3286 - val_accuracy: 0.8813
# Epoch 14/25
# 20/20 [==============================] - 18s 922ms/step - loss: 0.2515 - accuracy: 0.9422 - val_loss: 0.3214 - val_accuracy: 0.8750
# Epoch 15/25
# 20/20 [==============================] - 20s 986ms/step - loss: 0.2518 - accuracy: 0.9344 - val_loss: 0.3186 - val_accuracy: 0.8875
# Epoch 16/25
# 20/20 [==============================] - 20s 986ms/step - loss: 0.2184 - accuracy: 0.9453 - val_loss: 0.3026 - val_accuracy: 0.9000
# Epoch 17/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.2041 - accuracy: 0.9594 - val_loss: 0.3039 - val_accuracy: 0.8875
# Epoch 18/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.1991 - accuracy: 0.9594 - val_loss: 0.2924 - val_accuracy: 0.9125
# Epoch 19/25
# 20/20 [==============================] - 18s 924ms/step - loss: 0.1793 - accuracy: 0.9594 - val_loss: 0.2855 - val_accuracy: 0.9125
# Epoch 20/25
# 20/20 [==============================] - 20s 986ms/step - loss: 0.1681 - accuracy: 0.9766 - val_loss: 0.2767 - val_accuracy: 0.9062
# Epoch 21/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.1411 - accuracy: 0.9859 - val_loss: 0.2653 - val_accuracy: 0.8938
# Epoch 22/25
# 20/20 [==============================] - 20s 983ms/step - loss: 0.1532 - accuracy: 0.9797 - val_loss: 0.2785 - val_accuracy: 0.8938
# Epoch 23/25
# 20/20 [==============================] - 18s 925ms/step - loss: 0.1396 - accuracy: 0.9797 - val_loss: 0.2572 - val_accuracy: 0.9000
# Epoch 24/25
# 20/20 [==============================] - 20s 986ms/step - loss: 0.1250 - accuracy: 0.9859 - val_loss: 0.2508 - val_accuracy: 0.9187
# Epoch 25/25
# 20/20 [==============================] - 20s 985ms/step - loss: 0.1164 - accuracy: 0.9844 - val_loss: 0.2507 - val_accuracy: 0.9125
# **Performance on Validation data**
# [[83 17]
#  [ 6 94]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88       100
#            1       0.85      0.94      0.89       100
#
#     accuracy                           0.89       200
#    macro avg       0.89      0.89      0.88       200
# weighted avg       0.89      0.89      0.88       200
#
#   94
#   83
#  17
#   6
#
# Trial Metrics:
# Sensitivity: 0.94
# Specifity: 0.83
# Precision: 0.8468468468468469
# Score for fold 5: loss of 0.309246689081192; accuracy of 88.49999904632568%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.30973127484321594 - Accuracy: 86.50000095367432%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.37607502937316895 - Accuracy: 86.00000143051147%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.3648098111152649 - Accuracy: 81.49999976158142%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.3383306562900543 - Accuracy: 87.5%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.309246689081192 - Accuracy: 88.49999904632568%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 86.00000023841858 (+- 2.4083188464600607)
# > Loss: 0.33963869214057923 (+- 0.02749920114662049)
# > Sensitivity: 0.9480000000000001 (+- 0.0406939798987516)
# > Specifity: 0.772 (+- 0.04019950248448357)
# > Precision: 0.8070700686700688 (+- 0.027200165144782587)
# ------------------------------------------------------------------------
