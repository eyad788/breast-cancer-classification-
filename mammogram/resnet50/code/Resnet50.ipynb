# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".jpg":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_train',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_train',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_test',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_test',224))
benign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_validation',224))
malign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_validation',224))
# Out:
# 100%|██████████| 300/300 [00:48<00:00,  6.19it/s]
# 100%|██████████| 300/300 [00:38<00:00,  7.80it/s]
# 100%|██████████| 100/100 [00:16<00:00,  6.08it/s]
# 100%|██████████| 100/100 [00:13<00:00,  7.65it/s]
# 100%|██████████| 100/100 [00:19<00:00,  5.13it/s]
# 100%|██████████| 100/100 [00:14<00:00,  6.96it/s]

# %%
print('Resized Dimensions : ',benign_train.shape)
print('Resized Dimensions : ',benign_test.shape)
print('Resized Dimensions : ',malign_train.shape)
print('Resized Dimensions : ',malign_test.shape)
print('Resized Dimensions : ',malign_validation.shape)
print('Resized Dimensions : ',malign_validation.shape)
# Out:
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)

# %%
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))
benign_validation_label = np.zeros(len(benign_validation))
malign_validation_label = np.ones(len(malign_validation))

# %%
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)
X_val = np.concatenate((benign_validation, malign_validation),axis=0)
Y_val = np.concatenate((benign_validation_label, malign_validation_label),axis=0)

# %%
s1 = np.arange(X_train.shape[0])
np.random.shuffle(s1)
X_train = X_train[s1]
Y_train = Y_train[s1]

# %%
s2 = np.arange(X_test.shape[0])
np.random.shuffle(s2)
X_test = X_test[s2]
Y_test = Y_test[s2]

# %%
s3 = np.arange(X_val.shape[0])
np.random.shuffle(s3)
X_val = X_val[s3]
Y_val = Y_val[s3]

# %%
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)
Y_val = to_categorical(Y_val, num_classes= 2)

# %%
# # Display first 15 images , and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from keras.applications.vgg19 import VGG19

# %%
def build_model(backbone, learning_rate=1e-5):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(2, activation='softmax'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=learning_rate),
        metrics=['accuracy']
    )
    
    return model

# %%
K.clear_session()
gc.collect()

resnet =ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)


 


model = build_model(resnet ,learning_rate = 1e-5)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 23,858,434
# Trainable params: 23,801,218
# Non-trainable params: 57,216
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=10,verbose=1,factor=0.2, min_lr=1e-7)
early_stopping = EarlyStopping(monitor='val_accuracy', patience=20,verbose=1, mode='max')

# Checkpoint
filepath="raw.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit(
    X_train,Y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val,Y_val),
    callbacks=[learn_control, checkpoint ,early_stopping],
    shuffle=True
)
# Out:
# Epoch 1/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8211 - accuracy: 0.5350
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to raw.best.hdf5
# 19/19 [==============================] - 30s 1s/step - loss: 0.8211 - accuracy: 0.5350 - val_loss: 0.8195 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 2/100
# 19/19 [==============================] - ETA: 0s - loss: 0.7110 - accuracy: 0.6067
# Epoch 2: val_accuracy did not improve from 0.50000
# 19/19 [==============================] - 14s 734ms/step - loss: 0.7110 - accuracy: 0.6067 - val_loss: 0.8078 - val_accuracy: 0.5000 - lr: 1.0000e-05
# Epoch 3/100
# 19/19 [==============================] - ETA: 0s - loss: 0.5975 - accuracy: 0.6900
# Epoch 3: val_accuracy improved from 0.50000 to 0.50500, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 820ms/step - loss: 0.5975 - accuracy: 0.6900 - val_loss: 0.7701 - val_accuracy: 0.5050 - lr: 1.0000e-05
# Epoch 4/100
# 19/19 [==============================] - ETA: 0s - loss: 0.5371 - accuracy: 0.7383
# Epoch 4: val_accuracy did not improve from 0.50500
# 19/19 [==============================] - 14s 735ms/step - loss: 0.5371 - accuracy: 0.7383 - val_loss: 0.7279 - val_accuracy: 0.5050 - lr: 1.0000e-05
# Epoch 5/100
# 19/19 [==============================] - ETA: 0s - loss: 0.4462 - accuracy: 0.8283
# Epoch 5: val_accuracy did not improve from 0.50500
# 19/19 [==============================] - 14s 734ms/step - loss: 0.4462 - accuracy: 0.8283 - val_loss: 0.6907 - val_accuracy: 0.5050 - lr: 1.0000e-05
# Epoch 6/100
# 19/19 [==============================] - ETA: 0s - loss: 0.4057 - accuracy: 0.8450
# Epoch 6: val_accuracy improved from 0.50500 to 0.54000, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 819ms/step - loss: 0.4057 - accuracy: 0.8450 - val_loss: 0.6471 - val_accuracy: 0.5400 - lr: 1.0000e-05
# Epoch 7/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3303 - accuracy: 0.8867
# Epoch 7: val_accuracy improved from 0.54000 to 0.60000, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 813ms/step - loss: 0.3303 - accuracy: 0.8867 - val_loss: 0.6045 - val_accuracy: 0.6000 - lr: 1.0000e-05
# Epoch 8/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.9283
# Epoch 8: val_accuracy improved from 0.60000 to 0.65000, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 816ms/step - loss: 0.2823 - accuracy: 0.9283 - val_loss: 0.5675 - val_accuracy: 0.6500 - lr: 1.0000e-05
# Epoch 9/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2592 - accuracy: 0.9267
# Epoch 9: val_accuracy improved from 0.65000 to 0.72500, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 817ms/step - loss: 0.2592 - accuracy: 0.9267 - val_loss: 0.5315 - val_accuracy: 0.7250 - lr: 1.0000e-05
# Epoch 10/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2203 - accuracy: 0.9517
# Epoch 10: val_accuracy improved from 0.72500 to 0.75000, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 817ms/step - loss: 0.2203 - accuracy: 0.9517 - val_loss: 0.5048 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 11/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.9750
# Epoch 11: val_accuracy improved from 0.75000 to 0.76000, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 822ms/step - loss: 0.1872 - accuracy: 0.9750 - val_loss: 0.4819 - val_accuracy: 0.7600 - lr: 1.0000e-05
# Epoch 12/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1464 - accuracy: 0.9833
# Epoch 12: val_accuracy improved from 0.76000 to 0.77500, saving model to raw.best.hdf5
# 19/19 [==============================] - 17s 885ms/step - loss: 0.1464 - accuracy: 0.9833 - val_loss: 0.4653 - val_accuracy: 0.7750 - lr: 1.0000e-05
# Epoch 13/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 0.9850
# Epoch 13: val_accuracy improved from 0.77500 to 0.80000, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 819ms/step - loss: 0.1274 - accuracy: 0.9850 - val_loss: 0.4453 - val_accuracy: 0.8000 - lr: 1.0000e-05
# Epoch 14/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9883
# Epoch 14: val_accuracy improved from 0.80000 to 0.82500, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 815ms/step - loss: 0.1125 - accuracy: 0.9883 - val_loss: 0.4231 - val_accuracy: 0.8250 - lr: 1.0000e-05
# Epoch 15/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.9933
# Epoch 15: val_accuracy improved from 0.82500 to 0.85500, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 814ms/step - loss: 0.0908 - accuracy: 0.9933 - val_loss: 0.3914 - val_accuracy: 0.8550 - lr: 1.0000e-05
# Epoch 16/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9967
# Epoch 16: val_accuracy improved from 0.85500 to 0.87000, saving model to raw.best.hdf5
# 19/19 [==============================] - 17s 886ms/step - loss: 0.0758 - accuracy: 0.9967 - val_loss: 0.3710 - val_accuracy: 0.8700 - lr: 1.0000e-05
# Epoch 17/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9983
# Epoch 17: val_accuracy improved from 0.87000 to 0.88500, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 819ms/step - loss: 0.0606 - accuracy: 0.9983 - val_loss: 0.3552 - val_accuracy: 0.8850 - lr: 1.0000e-05
# Epoch 18/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 1.0000
# Epoch 18: val_accuracy improved from 0.88500 to 0.89500, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 818ms/step - loss: 0.0577 - accuracy: 1.0000 - val_loss: 0.3391 - val_accuracy: 0.8950 - lr: 1.0000e-05
# Epoch 19/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 1.0000
# Epoch 19: val_accuracy improved from 0.89500 to 0.90500, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 814ms/step - loss: 0.0489 - accuracy: 1.0000 - val_loss: 0.3294 - val_accuracy: 0.9050 - lr: 1.0000e-05
# Epoch 20/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9983
# Epoch 20: val_accuracy did not improve from 0.90500
# 19/19 [==============================] - 14s 739ms/step - loss: 0.0462 - accuracy: 0.9983 - val_loss: 0.3243 - val_accuracy: 0.9050 - lr: 1.0000e-05
# Epoch 21/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.90500
# 19/19 [==============================] - 14s 739ms/step - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.3106 - val_accuracy: 0.9050 - lr: 1.0000e-05
# Epoch 22/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9983
# Epoch 22: val_accuracy improved from 0.90500 to 0.91000, saving model to raw.best.hdf5
# 19/19 [==============================] - 16s 825ms/step - loss: 0.0347 - accuracy: 0.9983 - val_loss: 0.3029 - val_accuracy: 0.9100 - lr: 1.0000e-05
# Epoch 23/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.91000
# 19/19 [==============================] - 15s 809ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.3047 - val_accuracy: 0.9100 - lr: 1.0000e-05
# Epoch 24/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 1.0000
# Epoch 24: val_accuracy improved from 0.91000 to 0.91500, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 820ms/step - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.3058 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 25/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9983
# Epoch 25: val_accuracy did not improve from 0.91500
# 19/19 [==============================] - 14s 738ms/step - loss: 0.0306 - accuracy: 0.9983 - val_loss: 0.3037 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 26/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.91500
# 19/19 [==============================] - 14s 734ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.3063 - val_accuracy: 0.9150 - lr: 1.0000e-05
# Epoch 27/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 1.0000
# Epoch 27: val_accuracy improved from 0.91500 to 0.92000, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 814ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.2892 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 28/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 1.0000
# Epoch 28: val_accuracy improved from 0.92000 to 0.92500, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 812ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.2833 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 29/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 14s 734ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.2677 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 30/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 14s 737ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.2561 - val_accuracy: 0.9250 - lr: 1.0000e-05
# Epoch 31/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.92500
# 19/19 [==============================] - 14s 743ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.2600 - val_accuracy: 0.9200 - lr: 1.0000e-05
# Epoch 32/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9983
# Epoch 32: val_accuracy improved from 0.92500 to 0.93000, saving model to raw.best.hdf5
# 19/19 [==============================] - 16s 863ms/step - loss: 0.0205 - accuracy: 0.9983 - val_loss: 0.2769 - val_accuracy: 0.9300 - lr: 1.0000e-05
# Epoch 33/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.93000
# 19/19 [==============================] - 14s 747ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2660 - val_accuracy: 0.9300 - lr: 1.0000e-05
# Epoch 34/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 34: val_accuracy improved from 0.93000 to 0.94000, saving model to raw.best.hdf5
# 19/19 [==============================] - 16s 868ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.2496 - val_accuracy: 0.9400 - lr: 1.0000e-05
# Epoch 35/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 35: val_accuracy improved from 0.94000 to 0.94500, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 810ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2415 - val_accuracy: 0.9450 - lr: 1.0000e-05
# Epoch 36/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.94500
# 19/19 [==============================] - 14s 734ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2480 - val_accuracy: 0.9450 - lr: 1.0000e-05
# Epoch 37/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.94500
# 19/19 [==============================] - 14s 735ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.2635 - val_accuracy: 0.9350 - lr: 1.0000e-05
# Epoch 38/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.94500
# 19/19 [==============================] - 14s 735ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.2620 - val_accuracy: 0.9450 - lr: 1.0000e-05
# Epoch 39/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.94500
# 19/19 [==============================] - 14s 736ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2593 - val_accuracy: 0.9450 - lr: 1.0000e-05
# Epoch 40/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.94500
# 19/19 [==============================] - 15s 805ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2722 - val_accuracy: 0.9450 - lr: 1.0000e-05
# Epoch 41/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 41: val_accuracy improved from 0.94500 to 0.95500, saving model to raw.best.hdf5
# 19/19 [==============================] - 16s 826ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2736 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 42/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.95500
# 19/19 [==============================] - 14s 734ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2705 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 43/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9983
# Epoch 43: val_accuracy did not improve from 0.95500
# 19/19 [==============================] - 14s 734ms/step - loss: 0.0103 - accuracy: 0.9983 - val_loss: 0.2699 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 44/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 44: val_accuracy improved from 0.95500 to 0.96000, saving model to raw.best.hdf5
# 19/19 [==============================] - 15s 807ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.2668 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 45/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 737ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2674 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 46/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 743ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2632 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 47/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 744ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2654 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 48/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 742ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2698 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 49/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 742ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2678 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 50/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 735ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2725 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 51/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 736ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.2783 - val_accuracy: 0.9500 - lr: 1.0000e-05
# Epoch 52/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 737ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2744 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 53/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 735ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2789 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 54/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
#
# Epoch 54: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 735ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2814 - val_accuracy: 0.9550 - lr: 1.0000e-05
# Epoch 55/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 735ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2793 - val_accuracy: 0.9550 - lr: 2.0000e-06
# Epoch 56/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 736ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2775 - val_accuracy: 0.9550 - lr: 2.0000e-06
# Epoch 57/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 735ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2749 - val_accuracy: 0.9550 - lr: 2.0000e-06
# Epoch 58/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 736ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2728 - val_accuracy: 0.9550 - lr: 2.0000e-06
# Epoch 59/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 735ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2722 - val_accuracy: 0.9550 - lr: 2.0000e-06
# Epoch 60/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 741ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2718 - val_accuracy: 0.9550 - lr: 2.0000e-06
# Epoch 61/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 737ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2723 - val_accuracy: 0.9550 - lr: 2.0000e-06
# Epoch 62/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 739ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2750 - val_accuracy: 0.9550 - lr: 2.0000e-06
# Epoch 63/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 63: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 15s 813ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2773 - val_accuracy: 0.9550 - lr: 2.0000e-06
# Epoch 64/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 64: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
#
# Epoch 64: val_accuracy did not improve from 0.96000
# 19/19 [==============================] - 14s 744ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2760 - val_accuracy: 0.9550 - lr: 2.0000e-06
# Epoch 64: early stopping

# %%
train_loss_fe = history.history['loss']
train_acc_fe = history.history['accuracy']
val_loss_fe = history.history['val_loss']
val_acc_fe = history.history['val_accuracy']

epochs_fe = range(1, len(train_acc_fe)+1)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_fe, train_acc_fe, label='Training Accuracy')
plt.plot(epochs_fe, val_acc_fe, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_fe,train_loss_fe , label='Training Loss')
plt.plot(epochs_fe, val_loss_fe, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.load_weights("raw.best.hdf5")

# %%
Y_val_pred = model.predict(X_val)

# %%
accuracy_score(np.argmax(Y_val, axis=1), np.argmax(Y_val_pred, axis=1))
# Out:
# 0.96

# %%
from time import sleep
import time
start = time.process_time() 
Y_pred = model.predict(X_test)
end = time.process_time()
print("Time per image: {} ".format((end-start)/len(X_test)))
# Out:
# Time per image: 0.007054837319999479

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for breast cancer')
# Out:
# Confusion matrix, without normalization
# [[74 26]
#  [ 8 92]]

# %%
from sklearn.metrics import classification_report
print(classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.74      0.81       100
#            1       0.78      0.92      0.84       100
#
#     accuracy                           0.83       200
#    macro avg       0.84      0.83      0.83       200
# weighted avg       0.84      0.83      0.83       200

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

plt.close()
