# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".jpg":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_train',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_train',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_test',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_test',224))
benign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/benign_validation',224))
malign_validation = np.array(Dataset_loader('/content/drive/MyDrive/code ddsm 2(new)/malignant_validation',224))
# Out:
# 100%|██████████| 300/300 [00:42<00:00,  6.98it/s]
# 100%|██████████| 300/300 [00:38<00:00,  7.70it/s]
# 100%|██████████| 100/100 [00:16<00:00,  5.92it/s]
# 100%|██████████| 100/100 [00:12<00:00,  7.74it/s]
# 100%|██████████| 100/100 [00:18<00:00,  5.52it/s]
# 100%|██████████| 100/100 [00:15<00:00,  6.57it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('Resized Dimensions : ',benign_train.shape)
print('Resized Dimensions : ',benign_test.shape)
print('Resized Dimensions : ',malign_train.shape)
print('Resized Dimensions : ',malign_test.shape)
print('Resized Dimensions : ',malign_validation.shape)
print('Resized Dimensions : ',malign_validation.shape)
# Out:
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (300, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)
# Resized Dimensions :  (100, 224, 224, 3)

# %%
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))
benign_validation_label = np.zeros(len(benign_validation))
malign_validation_label = np.ones(len(malign_validation))

# %%
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)
X_val = np.concatenate((benign_validation, malign_validation),axis=0)
Y_val = np.concatenate((benign_validation_label, malign_validation_label),axis=0)

# %%
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# %%
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
s = np.arange(X_val.shape[0])
np.random.shuffle(s)
X_val = X_val[s]
Y_val = Y_val[s]

# %%
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)
Y_val = to_categorical(Y_val, num_classes= 2)

# %%
acc_per_fold = []
loss_per_fold = []
sens_per_fold = [] 
spec_per_fold = []
prec_per_fold = []

# %%
inputs = np.concatenate((X_train, X_val), axis=0)
targets = np.concatenate((Y_train, Y_val), axis=0)

# %%
# # Display first 15 images , and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(targets[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(inputs[i], interpolation='nearest')
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications.inception_v3 import InceptionV3
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
kfold = KFold(n_splits=5, shuffle=True)

# K-fold Cross Validation model evaluation

fold_no = 1
for train, test in kfold.split(inputs, targets):
    
    
    def build_model(backbone, learning_rate=1e-5):
        
        model = Sequential()
        model.add(backbone)
        model.add(layers.GlobalAveragePooling2D())
        model.add(layers.Dropout(0.5))
        model.add(layers.BatchNormalization())
        model.add(Dense(128, activation='relu'))
        model.add(layers.Dense(2, activation='softmax'))
        
    
    
        model.compile(loss='binary_crossentropy',optimizer=Adam(learning_rate=learning_rate),metrics=['accuracy'])
    
        return model


    resnet = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3))


 
    model = build_model(resnet ,learning_rate = 1e-5)
    
    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    history = model.fit(
    inputs[train], targets[train],
    epochs=25,
    batch_size=32,
    validation_data=(inputs[test],targets[test]),
    shuffle=True
    )
    
    predictions = model.predict(X_test)
    true_classes = Y_test
    # evaluate validation performance
    print("**Performance on Validation data**")    
    cm = confusion_matrix(np.argmax(true_classes, axis=1), np.argmax(predictions, axis=1))
    print(cm)
    print(classification_report( np.argmax(true_classes, axis=1), np.argmax(predictions, axis=1)))

    TP = cm[1,1] # true positive 
    TN = cm[0,0] # true negative
    FN = cm[1,0] # false negative
    FP = cm[0,1] # false positive
    print(f"  {TP}\n  {TN}\n {FP}\n  {FN}\n ")
    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP/(TP+FN)
    # Specificity or true negative rate
    TNR = TN/(TN+FP) 
    # Precision or positive predictive value
    PPV = TP/(TP+FP)
    # Negative predictive value
    NPV = TN/(TN+FN)
    # Fall out or false positive rate
    FPR = FP/(FP+TN)
    # False negative rate
    FNR = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP)



    print(f"Trial Metrics:")
    print(f"Sensitivity: {TPR}\nSpecifity: {TNR}\nPrecision: {PPV} ")
    

    scores = model.evaluate(X_test, Y_test, verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%' )
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])
    sens_per_fold.append(TPR) 
    spec_per_fold.append(TNR)  
    prec_per_fold.append(PPV) 
   
    

    fold_no = fold_no + 1


# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)} (+- {np.std(loss_per_fold)})')
print(f'> Sensitivity: {np.mean(sens_per_fold)} (+- {np.std(sens_per_fold)})')
print(f'> Specifity: {np.mean(spec_per_fold)} (+- {np.std(spec_per_fold)})')
print(f'> Precision: {np.mean(prec_per_fold)} (+- {np.std(prec_per_fold)})')
print('------------------------------------------------------------------------')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/25
# 20/20 [==============================] - 34s 744ms/step - loss: 0.7822 - accuracy: 0.5891 - val_loss: 0.8916 - val_accuracy: 0.5063
# Epoch 2/25
# 20/20 [==============================] - 14s 699ms/step - loss: 0.6346 - accuracy: 0.7266 - val_loss: 0.8318 - val_accuracy: 0.6000
# Epoch 3/25
# 20/20 [==============================] - 14s 702ms/step - loss: 0.5537 - accuracy: 0.7703 - val_loss: 0.7599 - val_accuracy: 0.6375
# Epoch 4/25
# 20/20 [==============================] - 14s 703ms/step - loss: 0.4760 - accuracy: 0.8313 - val_loss: 0.6964 - val_accuracy: 0.6938
# Epoch 5/25
# 20/20 [==============================] - 14s 689ms/step - loss: 0.4124 - accuracy: 0.8734 - val_loss: 0.6453 - val_accuracy: 0.7312
# Epoch 6/25
# 20/20 [==============================] - 14s 705ms/step - loss: 0.3617 - accuracy: 0.8891 - val_loss: 0.6023 - val_accuracy: 0.7750
# Epoch 7/25
# 20/20 [==============================] - 14s 690ms/step - loss: 0.2968 - accuracy: 0.9172 - val_loss: 0.5684 - val_accuracy: 0.7812
# Epoch 8/25
# 20/20 [==============================] - 14s 706ms/step - loss: 0.2748 - accuracy: 0.9359 - val_loss: 0.5407 - val_accuracy: 0.8000
# Epoch 9/25
# 20/20 [==============================] - 14s 690ms/step - loss: 0.2224 - accuracy: 0.9484 - val_loss: 0.5201 - val_accuracy: 0.8125
# Epoch 10/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.1944 - accuracy: 0.9578 - val_loss: 0.5071 - val_accuracy: 0.8250
# Epoch 11/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.1698 - accuracy: 0.9688 - val_loss: 0.5024 - val_accuracy: 0.8250
# Epoch 12/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.1497 - accuracy: 0.9766 - val_loss: 0.4965 - val_accuracy: 0.8188
# Epoch 13/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.1320 - accuracy: 0.9906 - val_loss: 0.4926 - val_accuracy: 0.8062
# Epoch 14/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.1037 - accuracy: 0.9844 - val_loss: 0.4853 - val_accuracy: 0.8125
# Epoch 15/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0816 - accuracy: 0.9953 - val_loss: 0.4912 - val_accuracy: 0.8062
# Epoch 16/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0717 - accuracy: 0.9969 - val_loss: 0.4966 - val_accuracy: 0.8000
# Epoch 17/25
# 20/20 [==============================] - 14s 693ms/step - loss: 0.0606 - accuracy: 0.9984 - val_loss: 0.5011 - val_accuracy: 0.7937
# Epoch 18/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.0540 - accuracy: 0.9984 - val_loss: 0.5084 - val_accuracy: 0.7812
# Epoch 19/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0448 - accuracy: 0.9984 - val_loss: 0.5139 - val_accuracy: 0.7812
# Epoch 20/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0393 - accuracy: 1.0000 - val_loss: 0.5183 - val_accuracy: 0.7875
# Epoch 21/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.5174 - val_accuracy: 0.7812
# Epoch 22/25
# 20/20 [==============================] - 14s 707ms/step - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.7875
# Epoch 23/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.5014 - val_accuracy: 0.7812
# Epoch 24/25
# 20/20 [==============================] - 14s 690ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.5003 - val_accuracy: 0.8062
# Epoch 25/25
# 20/20 [==============================] - 14s 707ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.4999 - val_accuracy: 0.8250
# **Performance on Validation data**
# [[79 21]
#  [14 86]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82       100
#            1       0.80      0.86      0.83       100
#
#     accuracy                           0.82       200
#    macro avg       0.83      0.82      0.82       200
# weighted avg       0.83      0.82      0.82       200
#
#   86
#   79
#  21
#   14
#
# Trial Metrics:
# Sensitivity: 0.86
# Specifity: 0.79
# Precision: 0.8037383177570093
# Score for fold 1: loss of 0.41739845275878906; accuracy of 82.4999988079071%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/25
# 20/20 [==============================] - 22s 752ms/step - loss: 0.8190 - accuracy: 0.5453 - val_loss: 0.6496 - val_accuracy: 0.6500
# Epoch 2/25
# 20/20 [==============================] - 14s 705ms/step - loss: 0.6577 - accuracy: 0.6781 - val_loss: 0.5919 - val_accuracy: 0.7500
# Epoch 3/25
# 20/20 [==============================] - 14s 690ms/step - loss: 0.5419 - accuracy: 0.7812 - val_loss: 0.5603 - val_accuracy: 0.7688
# Epoch 4/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.4596 - accuracy: 0.8344 - val_loss: 0.5338 - val_accuracy: 0.7937
# Epoch 5/25
# 20/20 [==============================] - 14s 707ms/step - loss: 0.4054 - accuracy: 0.8578 - val_loss: 0.5115 - val_accuracy: 0.8125
# Epoch 6/25
# 20/20 [==============================] - 14s 707ms/step - loss: 0.3488 - accuracy: 0.8906 - val_loss: 0.4875 - val_accuracy: 0.8062
# Epoch 7/25
# 20/20 [==============================] - 14s 706ms/step - loss: 0.2839 - accuracy: 0.9266 - val_loss: 0.4710 - val_accuracy: 0.8062
# Epoch 8/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.2512 - accuracy: 0.9453 - val_loss: 0.4589 - val_accuracy: 0.8000
# Epoch 9/25
# 20/20 [==============================] - 14s 690ms/step - loss: 0.2134 - accuracy: 0.9500 - val_loss: 0.4495 - val_accuracy: 0.8250
# Epoch 10/25
# 20/20 [==============================] - 14s 707ms/step - loss: 0.1936 - accuracy: 0.9609 - val_loss: 0.4494 - val_accuracy: 0.7875
# Epoch 11/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.1429 - accuracy: 0.9766 - val_loss: 0.4452 - val_accuracy: 0.8062
# Epoch 12/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.1304 - accuracy: 0.9812 - val_loss: 0.4425 - val_accuracy: 0.8250
# Epoch 13/25
# 20/20 [==============================] - 14s 706ms/step - loss: 0.1133 - accuracy: 0.9844 - val_loss: 0.4493 - val_accuracy: 0.8188
# Epoch 14/25
# 20/20 [==============================] - 14s 707ms/step - loss: 0.0860 - accuracy: 0.9937 - val_loss: 0.4532 - val_accuracy: 0.8062
# Epoch 15/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0679 - accuracy: 0.9953 - val_loss: 0.4636 - val_accuracy: 0.8062
# Epoch 16/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0697 - accuracy: 0.9937 - val_loss: 0.4651 - val_accuracy: 0.8000
# Epoch 17/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0592 - accuracy: 0.9937 - val_loss: 0.4779 - val_accuracy: 0.8000
# Epoch 18/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.4919 - val_accuracy: 0.8188
# Epoch 19/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.0517 - accuracy: 0.9922 - val_loss: 0.4949 - val_accuracy: 0.8125
# Epoch 20/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 0.4911 - val_accuracy: 0.8000
# Epoch 21/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.4908 - val_accuracy: 0.8000
# Epoch 22/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.4806 - val_accuracy: 0.8062
# Epoch 23/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.4759 - val_accuracy: 0.8062
# Epoch 24/25
# 20/20 [==============================] - 14s 707ms/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.4674 - val_accuracy: 0.8250
# Epoch 25/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.4593 - val_accuracy: 0.8250
# **Performance on Validation data**
# [[72 28]
#  [12 88]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.72      0.78       100
#            1       0.76      0.88      0.81       100
#
#     accuracy                           0.80       200
#    macro avg       0.81      0.80      0.80       200
# weighted avg       0.81      0.80      0.80       200
#
#   88
#   72
#  28
#   12
#
# Trial Metrics:
# Sensitivity: 0.88
# Specifity: 0.72
# Precision: 0.7586206896551724
# Score for fold 2: loss of 0.4297841191291809; accuracy of 80.0000011920929%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/25
# 20/20 [==============================] - 23s 761ms/step - loss: 0.8219 - accuracy: 0.5813 - val_loss: 0.7500 - val_accuracy: 0.5063
# Epoch 2/25
# 20/20 [==============================] - 14s 706ms/step - loss: 0.6580 - accuracy: 0.7297 - val_loss: 0.6925 - val_accuracy: 0.5875
# Epoch 3/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.5322 - accuracy: 0.7891 - val_loss: 0.6387 - val_accuracy: 0.6687
# Epoch 4/25
# 20/20 [==============================] - 14s 707ms/step - loss: 0.4928 - accuracy: 0.8172 - val_loss: 0.6022 - val_accuracy: 0.7188
# Epoch 5/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.3962 - accuracy: 0.8750 - val_loss: 0.5746 - val_accuracy: 0.7250
# Epoch 6/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.3411 - accuracy: 0.8844 - val_loss: 0.5578 - val_accuracy: 0.7563
# Epoch 7/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.2848 - accuracy: 0.9297 - val_loss: 0.5527 - val_accuracy: 0.7688
# Epoch 8/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.2614 - accuracy: 0.9375 - val_loss: 0.5519 - val_accuracy: 0.7625
# Epoch 9/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.2226 - accuracy: 0.9406 - val_loss: 0.5524 - val_accuracy: 0.7750
# Epoch 10/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.2061 - accuracy: 0.9500 - val_loss: 0.5573 - val_accuracy: 0.7437
# Epoch 11/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.1551 - accuracy: 0.9797 - val_loss: 0.5527 - val_accuracy: 0.7625
# Epoch 12/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.1402 - accuracy: 0.9766 - val_loss: 0.5403 - val_accuracy: 0.7750
# Epoch 13/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.1106 - accuracy: 0.9875 - val_loss: 0.5397 - val_accuracy: 0.7563
# Epoch 14/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.1007 - accuracy: 0.9891 - val_loss: 0.5413 - val_accuracy: 0.7625
# Epoch 15/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.0862 - accuracy: 0.9906 - val_loss: 0.5380 - val_accuracy: 0.7625
# Epoch 16/25
# 20/20 [==============================] - 14s 710ms/step - loss: 0.0717 - accuracy: 0.9937 - val_loss: 0.5303 - val_accuracy: 0.7750
# Epoch 17/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.0616 - accuracy: 0.9984 - val_loss: 0.5212 - val_accuracy: 0.7937
# Epoch 18/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.0489 - accuracy: 0.9969 - val_loss: 0.5164 - val_accuracy: 0.7812
# Epoch 19/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.0445 - accuracy: 1.0000 - val_loss: 0.5014 - val_accuracy: 0.7937
# Epoch 20/25
# 20/20 [==============================] - 14s 708ms/step - loss: 0.0438 - accuracy: 0.9984 - val_loss: 0.4901 - val_accuracy: 0.7875
# Epoch 21/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.4792 - val_accuracy: 0.8062
# Epoch 22/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.4739 - val_accuracy: 0.8375
# Epoch 23/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.0298 - accuracy: 0.9984 - val_loss: 0.4658 - val_accuracy: 0.8313
# Epoch 24/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0240 - accuracy: 0.9984 - val_loss: 0.4563 - val_accuracy: 0.8375
# Epoch 25/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.4482 - val_accuracy: 0.8562
# **Performance on Validation data**
# [[77 23]
#  [14 86]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81       100
#            1       0.79      0.86      0.82       100
#
#     accuracy                           0.81       200
#    macro avg       0.82      0.81      0.81       200
# weighted avg       0.82      0.81      0.81       200
#
#   86
#   77
#  23
#   14
#
# Trial Metrics:
# Sensitivity: 0.86
# Specifity: 0.77
# Precision: 0.7889908256880734
# Score for fold 3: loss of 0.4346415400505066; accuracy of 81.49999976158142%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/25
# 20/20 [==============================] - 23s 758ms/step - loss: 0.7781 - accuracy: 0.5734 - val_loss: 0.7238 - val_accuracy: 0.5312
# Epoch 2/25
# 20/20 [==============================] - 14s 706ms/step - loss: 0.6167 - accuracy: 0.7328 - val_loss: 0.6581 - val_accuracy: 0.6000
# Epoch 3/25
# 20/20 [==============================] - 14s 690ms/step - loss: 0.5448 - accuracy: 0.7875 - val_loss: 0.6133 - val_accuracy: 0.6625
# Epoch 4/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.4504 - accuracy: 0.8578 - val_loss: 0.5701 - val_accuracy: 0.7500
# Epoch 5/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.3969 - accuracy: 0.8844 - val_loss: 0.5282 - val_accuracy: 0.8188
# Epoch 6/25
# 20/20 [==============================] - 14s 707ms/step - loss: 0.3393 - accuracy: 0.9141 - val_loss: 0.4953 - val_accuracy: 0.8188
# Epoch 7/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.2868 - accuracy: 0.9281 - val_loss: 0.4718 - val_accuracy: 0.8188
# Epoch 8/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.2291 - accuracy: 0.9578 - val_loss: 0.4509 - val_accuracy: 0.8188
# Epoch 9/25
# 20/20 [==============================] - 14s 710ms/step - loss: 0.2161 - accuracy: 0.9484 - val_loss: 0.4365 - val_accuracy: 0.8375
# Epoch 10/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.1838 - accuracy: 0.9656 - val_loss: 0.4238 - val_accuracy: 0.8562
# Epoch 11/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.1570 - accuracy: 0.9719 - val_loss: 0.4195 - val_accuracy: 0.8438
# Epoch 12/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.1185 - accuracy: 0.9844 - val_loss: 0.4091 - val_accuracy: 0.8438
# Epoch 13/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0917 - accuracy: 0.9922 - val_loss: 0.4017 - val_accuracy: 0.8687
# Epoch 14/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0878 - accuracy: 0.9922 - val_loss: 0.3958 - val_accuracy: 0.8500
# Epoch 15/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0629 - accuracy: 0.9969 - val_loss: 0.3884 - val_accuracy: 0.8625
# Epoch 16/25
# 20/20 [==============================] - 14s 710ms/step - loss: 0.0536 - accuracy: 0.9984 - val_loss: 0.3878 - val_accuracy: 0.8750
# Epoch 17/25
# 20/20 [==============================] - 14s 710ms/step - loss: 0.0526 - accuracy: 1.0000 - val_loss: 0.3838 - val_accuracy: 0.8562
# Epoch 18/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.0700 - accuracy: 0.9922 - val_loss: 0.3873 - val_accuracy: 0.8438
# Epoch 19/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0413 - accuracy: 1.0000 - val_loss: 0.3808 - val_accuracy: 0.8438
# Epoch 20/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0424 - accuracy: 1.0000 - val_loss: 0.3702 - val_accuracy: 0.8625
# Epoch 21/25
# 20/20 [==============================] - 14s 691ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.3592 - val_accuracy: 0.8687
# Epoch 22/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.3513 - val_accuracy: 0.8562
# Epoch 23/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.3447 - val_accuracy: 0.8687
# Epoch 24/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0214 - accuracy: 0.9984 - val_loss: 0.3363 - val_accuracy: 0.8625
# Epoch 25/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.3250 - val_accuracy: 0.8875
# **Performance on Validation data**
# [[79 21]
#  [12 88]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83       100
#            1       0.81      0.88      0.84       100
#
#     accuracy                           0.83       200
#    macro avg       0.84      0.83      0.83       200
# weighted avg       0.84      0.83      0.83       200
#
#   88
#   79
#  21
#   12
#
# Trial Metrics:
# Sensitivity: 0.88
# Specifity: 0.79
# Precision: 0.8073394495412844
# Score for fold 4: loss of 0.38141852617263794; accuracy of 83.49999785423279%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/25
# 20/20 [==============================] - 23s 758ms/step - loss: 0.8542 - accuracy: 0.5328 - val_loss: 0.8292 - val_accuracy: 0.5000
# Epoch 2/25
# 20/20 [==============================] - 14s 688ms/step - loss: 0.6767 - accuracy: 0.6875 - val_loss: 0.7431 - val_accuracy: 0.5750
# Epoch 3/25
# 20/20 [==============================] - 14s 689ms/step - loss: 0.5805 - accuracy: 0.7437 - val_loss: 0.6698 - val_accuracy: 0.6375
# Epoch 4/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.4915 - accuracy: 0.7844 - val_loss: 0.6190 - val_accuracy: 0.6812
# Epoch 5/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.4160 - accuracy: 0.8594 - val_loss: 0.5913 - val_accuracy: 0.6875
# Epoch 6/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.3428 - accuracy: 0.8906 - val_loss: 0.5626 - val_accuracy: 0.7063
# Epoch 7/25
# 20/20 [==============================] - 14s 693ms/step - loss: 0.3221 - accuracy: 0.8922 - val_loss: 0.5433 - val_accuracy: 0.7125
# Epoch 8/25
# 20/20 [==============================] - 14s 710ms/step - loss: 0.2897 - accuracy: 0.9125 - val_loss: 0.5246 - val_accuracy: 0.7125
# Epoch 9/25
# 20/20 [==============================] - 14s 693ms/step - loss: 0.2317 - accuracy: 0.9469 - val_loss: 0.5163 - val_accuracy: 0.7375
# Epoch 10/25
# 20/20 [==============================] - 14s 693ms/step - loss: 0.1905 - accuracy: 0.9625 - val_loss: 0.5141 - val_accuracy: 0.7625
# Epoch 11/25
# 20/20 [==============================] - 14s 692ms/step - loss: 0.1695 - accuracy: 0.9703 - val_loss: 0.5143 - val_accuracy: 0.7688
# Epoch 12/25
# 20/20 [==============================] - 14s 710ms/step - loss: 0.1425 - accuracy: 0.9719 - val_loss: 0.5149 - val_accuracy: 0.7750
# Epoch 13/25
# 20/20 [==============================] - 14s 694ms/step - loss: 0.1271 - accuracy: 0.9844 - val_loss: 0.5195 - val_accuracy: 0.7688
# Epoch 14/25
# 20/20 [==============================] - 14s 710ms/step - loss: 0.0933 - accuracy: 0.9906 - val_loss: 0.5250 - val_accuracy: 0.7688
# Epoch 15/25
# 20/20 [==============================] - 14s 710ms/step - loss: 0.0863 - accuracy: 0.9891 - val_loss: 0.5309 - val_accuracy: 0.7750
# Epoch 16/25
# 20/20 [==============================] - 14s 693ms/step - loss: 0.0706 - accuracy: 0.9969 - val_loss: 0.5241 - val_accuracy: 0.7875
# Epoch 17/25
# 20/20 [==============================] - 14s 694ms/step - loss: 0.0781 - accuracy: 0.9953 - val_loss: 0.5277 - val_accuracy: 0.7875
# Epoch 18/25
# 20/20 [==============================] - 14s 695ms/step - loss: 0.0641 - accuracy: 0.9984 - val_loss: 0.5393 - val_accuracy: 0.7937
# Epoch 19/25
# 20/20 [==============================] - 14s 710ms/step - loss: 0.0460 - accuracy: 1.0000 - val_loss: 0.5420 - val_accuracy: 0.7937
# Epoch 20/25
# 20/20 [==============================] - 14s 710ms/step - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.5441 - val_accuracy: 0.7812
# Epoch 21/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.5425 - val_accuracy: 0.7812
# Epoch 22/25
# 20/20 [==============================] - 14s 709ms/step - loss: 0.0325 - accuracy: 0.9984 - val_loss: 0.5500 - val_accuracy: 0.7688
# Epoch 23/25
# 20/20 [==============================] - 14s 693ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.5477 - val_accuracy: 0.7750
# Epoch 24/25
# 20/20 [==============================] - 14s 693ms/step - loss: 0.0300 - accuracy: 0.9969 - val_loss: 0.5378 - val_accuracy: 0.7750
# Epoch 25/25
# 20/20 [==============================] - 14s 711ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.5390 - val_accuracy: 0.7688
# **Performance on Validation data**
# [[64 36]
#  [ 3 97]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.64      0.77       100
#            1       0.73      0.97      0.83       100
#
#     accuracy                           0.81       200
#    macro avg       0.84      0.80      0.80       200
# weighted avg       0.84      0.81      0.80       200
#
#   97
#   64
#  36
#   3
#
# Trial Metrics:
# Sensitivity: 0.97
# Specifity: 0.64
# Precision: 0.7293233082706767
# Score for fold 5: loss of 0.4113866090774536; accuracy of 80.50000071525574%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.41739845275878906 - Accuracy: 82.4999988079071%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.4297841191291809 - Accuracy: 80.0000011920929%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.4346415400505066 - Accuracy: 81.49999976158142%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.38141852617263794 - Accuracy: 83.49999785423279%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.4113866090774536 - Accuracy: 80.50000071525574%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 81.59999966621399 (+- 1.2806236261875437)
# > Loss: 0.4149258494377136 (+- 0.018712869028906908)
# > Sensitivity: 0.89 (+- 0.04098780306383839)
# > Specifity: 0.7420000000000001 (+- 0.05706137047074843)
# > Precision: 0.7776025181824433 (+- 0.029625160177890162)
# ------------------------------------------------------------------------
